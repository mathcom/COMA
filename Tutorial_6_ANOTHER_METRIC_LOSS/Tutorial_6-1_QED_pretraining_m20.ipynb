# %% [markdown]
# # Tutorial - VAE pretraining with a traditional metric loss; triplet loss

# %% [markdown]
# ## 1. Import requirements

# %%
import os
import sys
import pandas as pd
import torch
import time
import matplotlib.pyplot as plt

# %%
sys.path = [os.path.abspath(os.path.join(os.getcwd(), os.pardir))] + sys.path

# %%
from MTMR.dataset import TrainingSmilesDataset, ValidationSmilesDataset
from vae_triplet import SmilesAutoencoder

# %% [markdown]
# ## 2. Configure GPU (if available)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# ## 3. Specify a target property

# %%
PROPERTY_NAME = "qed"

# %% [markdown]
# ## 4. Set directories (for inputs and outputs)

# %%
input_dir = os.path.abspath(os.path.join(os.pardir, "DATA", PROPERTY_NAME))

# %%
output_dir = f"outputs_6-1_{PROPERTY_NAME.upper()}_pretraining_m20"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

# %% [markdown]
# ## 5. Set file names

# %%
filepath_train = os.path.join(input_dir, "rdkit_train_triplet.txt")
filepath_valid = os.path.join(input_dir, "rdkit_valid.txt")

# %%
filepath_char2idx      = os.path.join(output_dir, "char2idx.csv")
filepath_configs       = os.path.join(output_dir, "configs.csv")
filepath_checkpoint    = os.path.join(output_dir, "checkpoints.pt")
filepath_history       = os.path.join(output_dir, "history.csv")
filepath_history_valid = os.path.join(output_dir, "history_valid.csv")

# %% [markdown]
# ## 6. Load datasets (for training and validation)

# %%
dataset = TrainingSmilesDataset(filepath_train, device=device)
dataset.save_char2idx(filepath_char2idx)
dataset_valid = ValidationSmilesDataset(filepath_valid, filepath_char2idx, device=device)

# %% [markdown]
# ## 7. Initialize a generator of MTMR

# %%
## Model configuration
model_configs = {"hidden_size":128,
                 "latent_size":128,
                 "num_layers" :2,
                 "vocab_size" :dataset.vocab_size,
                 "sos_idx"    :dataset.sos_idx,
                 "eos_idx"    :dataset.eos_idx,
                 "pad_idx"    :dataset.pad_idx,
                 "device"     :device
                }

## Model initialization
generator = SmilesAutoencoder(**model_configs)

## Configuration save
generator.save_config(filepath_configs)

# %% [markdown]
# ## 8. Train

# %%
df_history, df_history_valid = generator.fit(dataset,
                                             validation_dataset=dataset_valid,
                                             margin=20.,
                                             checkpoint_filepath=filepath_checkpoint)

df_history.to_csv(filepath_history, index=False)
df_history_valid.to_csv(filepath_history_valid, index=False)
# Out:
# [00000000/00100000]  loss(tr): 201.686  loss_recon_src(tr): 3.381  loss_recon_tar(tr): 3.386  loss_recon_neg(tr): 3.379  loss_kld(tr): 2.013  loss_triplet(tr): 19.798  valid_ratio(va): 0.125  similarity(va): 0.003
# [00001000/00100000]  loss(tr): 182.705  loss_recon_src(tr): 0.596  loss_recon_tar(tr): 0.524  loss_recon_neg(tr): 0.579  loss_kld(tr): 14.912  loss_triplet(tr): 16.751
# [00002000/00100000]  loss(tr): 182.954  loss_recon_src(tr): 0.520  loss_recon_tar(tr): 0.460  loss_recon_neg(tr): 0.525  loss_kld(tr): 15.516  loss_triplet(tr): 16.719
# [00003000/00100000]  loss(tr): 182.371  loss_recon_src(tr): 0.512  loss_recon_tar(tr): 0.457  loss_recon_neg(tr): 0.469  loss_kld(tr): 17.511  loss_triplet(tr): 16.462
# [00004000/00100000]  loss(tr): 176.841  loss_recon_src(tr): 0.513  loss_recon_tar(tr): 0.436  loss_recon_neg(tr): 0.485  loss_kld(tr): 15.865  loss_triplet(tr): 16.074
# [00005000/00100000]  loss(tr): 158.832  loss_recon_src(tr): 0.507  loss_recon_tar(tr): 0.425  loss_recon_neg(tr): 0.479  loss_kld(tr): 35.317  loss_triplet(tr): 12.328
# [00006000/00100000]  loss(tr): 158.264  loss_recon_src(tr): 0.501  loss_recon_tar(tr): 0.416  loss_recon_neg(tr): 0.478  loss_kld(tr): 37.540  loss_triplet(tr): 12.049
# [00007000/00100000]  loss(tr): 161.459  loss_recon_src(tr): 0.510  loss_recon_tar(tr): 0.416  loss_recon_neg(tr): 0.449  loss_kld(tr): 37.366  loss_triplet(tr): 12.386
# [00008000/00100000]  loss(tr): 164.366  loss_recon_src(tr): 0.523  loss_recon_tar(tr): 0.427  loss_recon_neg(tr): 0.479  loss_kld(tr): 39.053  loss_triplet(tr): 12.507
# [00009000/00100000]  loss(tr): 151.840  loss_recon_src(tr): 0.513  loss_recon_tar(tr): 0.383  loss_recon_neg(tr): 0.438  loss_kld(tr): 39.717  loss_triplet(tr): 11.190
# [00010000/00100000]  loss(tr): 158.328  loss_recon_src(tr): 0.484  loss_recon_tar(tr): 0.384  loss_recon_neg(tr): 0.439  loss_kld(tr): 37.351  loss_triplet(tr): 12.076  valid_ratio(va): 1.000  similarity(va): 0.145
# [00011000/00100000]  loss(tr): 159.140  loss_recon_src(tr): 0.481  loss_recon_tar(tr): 0.370  loss_recon_neg(tr): 0.423  loss_kld(tr): 38.108  loss_triplet(tr): 12.082
# [00012000/00100000]  loss(tr): 147.774  loss_recon_src(tr): 0.473  loss_recon_tar(tr): 0.364  loss_recon_neg(tr): 0.429  loss_kld(tr): 39.294  loss_triplet(tr): 10.827
# [00013000/00100000]  loss(tr): 162.970  loss_recon_src(tr): 0.460  loss_recon_tar(tr): 0.365  loss_recon_neg(tr): 0.435  loss_kld(tr): 43.316  loss_triplet(tr): 11.944
# [00014000/00100000]  loss(tr): 163.131  loss_recon_src(tr): 0.475  loss_recon_tar(tr): 0.358  loss_recon_neg(tr): 0.422  loss_kld(tr): 39.877  loss_triplet(tr): 12.305
# [00015000/00100000]  loss(tr): 143.507  loss_recon_src(tr): 0.480  loss_recon_tar(tr): 0.346  loss_recon_neg(tr): 0.431  loss_kld(tr): 43.590  loss_triplet(tr): 9.971
# [00016000/00100000]  loss(tr): 169.704  loss_recon_src(tr): 0.471  loss_recon_tar(tr): 0.374  loss_recon_neg(tr): 0.402  loss_kld(tr): 41.769  loss_triplet(tr): 12.773
# [00017000/00100000]  loss(tr): 153.422  loss_recon_src(tr): 0.456  loss_recon_tar(tr): 0.344  loss_recon_neg(tr): 0.421  loss_kld(tr): 41.887  loss_triplet(tr): 11.133
# [00018000/00100000]  loss(tr): 162.753  loss_recon_src(tr): 0.475  loss_recon_tar(tr): 0.352  loss_recon_neg(tr): 0.377  loss_kld(tr): 44.993  loss_triplet(tr): 11.756
# [00019000/00100000]  loss(tr): 159.138  loss_recon_src(tr): 0.476  loss_recon_tar(tr): 0.348  loss_recon_neg(tr): 0.409  loss_kld(tr): 42.757  loss_triplet(tr): 11.618
# [00020000/00100000]  loss(tr): 154.475  loss_recon_src(tr): 0.458  loss_recon_tar(tr): 0.342  loss_recon_neg(tr): 0.402  loss_kld(tr): 42.049  loss_triplet(tr): 11.223  valid_ratio(va): 1.000  similarity(va): 0.148
# [00021000/00100000]  loss(tr): 159.885  loss_recon_src(tr): 0.469  loss_recon_tar(tr): 0.352  loss_recon_neg(tr): 0.417  loss_kld(tr): 43.340  loss_triplet(tr): 11.634
# [00022000/00100000]  loss(tr): 156.920  loss_recon_src(tr): 0.444  loss_recon_tar(tr): 0.321  loss_recon_neg(tr): 0.404  loss_kld(tr): 43.982  loss_triplet(tr): 11.274
# [00023000/00100000]  loss(tr): 150.584  loss_recon_src(tr): 0.452  loss_recon_tar(tr): 0.333  loss_recon_neg(tr): 0.408  loss_kld(tr): 42.785  loss_triplet(tr): 10.760
# [00024000/00100000]  loss(tr): 154.195  loss_recon_src(tr): 0.440  loss_recon_tar(tr): 0.320  loss_recon_neg(tr): 0.395  loss_kld(tr): 42.058  loss_triplet(tr): 11.194
# [00025000/00100000]  loss(tr): 151.664  loss_recon_src(tr): 0.467  loss_recon_tar(tr): 0.360  loss_recon_neg(tr): 0.378  loss_kld(tr): 45.222  loss_triplet(tr): 10.624
# [00026000/00100000]  loss(tr): 148.081  loss_recon_src(tr): 0.436  loss_recon_tar(tr): 0.343  loss_recon_neg(tr): 0.389  loss_kld(tr): 46.360  loss_triplet(tr): 10.153
# [00027000/00100000]  loss(tr): 154.254  loss_recon_src(tr): 0.454  loss_recon_tar(tr): 0.328  loss_recon_neg(tr): 0.402  loss_kld(tr): 44.020  loss_triplet(tr): 11.004
# [00028000/00100000]  loss(tr): 157.387  loss_recon_src(tr): 0.460  loss_recon_tar(tr): 0.344  loss_recon_neg(tr): 0.373  loss_kld(tr): 44.746  loss_triplet(tr): 11.245
# [00029000/00100000]  loss(tr): 156.760  loss_recon_src(tr): 0.422  loss_recon_tar(tr): 0.317  loss_recon_neg(tr): 0.386  loss_kld(tr): 46.257  loss_triplet(tr): 11.031
# [00030000/00100000]  loss(tr): 148.756  loss_recon_src(tr): 0.432  loss_recon_tar(tr): 0.302  loss_recon_neg(tr): 0.400  loss_kld(tr): 47.878  loss_triplet(tr): 10.069  valid_ratio(va): 1.000  similarity(va): 0.149
# [00031000/00100000]  loss(tr): 167.927  loss_recon_src(tr): 0.432  loss_recon_tar(tr): 0.312  loss_recon_neg(tr): 0.382  loss_kld(tr): 47.420  loss_triplet(tr): 12.032
# [00032000/00100000]  loss(tr): 175.638  loss_recon_src(tr): 0.451  loss_recon_tar(tr): 0.333  loss_recon_neg(tr): 0.405  loss_kld(tr): 47.093  loss_triplet(tr): 12.835
# [00033000/00100000]  loss(tr): 173.758  loss_recon_src(tr): 0.440  loss_recon_tar(tr): 0.330  loss_recon_neg(tr): 0.410  loss_kld(tr): 45.587  loss_triplet(tr): 12.797
# [00034000/00100000]  loss(tr): 166.416  loss_recon_src(tr): 0.439  loss_recon_tar(tr): 0.326  loss_recon_neg(tr): 0.396  loss_kld(tr): 43.959  loss_triplet(tr): 12.226
# [00035000/00100000]  loss(tr): 161.495  loss_recon_src(tr): 0.432  loss_recon_tar(tr): 0.333  loss_recon_neg(tr): 0.380  loss_kld(tr): 44.584  loss_triplet(tr): 11.672
# [00036000/00100000]  loss(tr): 148.683  loss_recon_src(tr): 0.433  loss_recon_tar(tr): 0.331  loss_recon_neg(tr): 0.384  loss_kld(tr): 45.223  loss_triplet(tr): 10.327
# [00037000/00100000]  loss(tr): 156.312  loss_recon_src(tr): 0.439  loss_recon_tar(tr): 0.304  loss_recon_neg(tr): 0.390  loss_kld(tr): 47.413  loss_triplet(tr): 10.871
# [00038000/00100000]  loss(tr): 156.963  loss_recon_src(tr): 0.448  loss_recon_tar(tr): 0.326  loss_recon_neg(tr): 0.370  loss_kld(tr): 43.718  loss_triplet(tr): 11.306
# [00039000/00100000]  loss(tr): 151.125  loss_recon_src(tr): 0.436  loss_recon_tar(tr): 0.296  loss_recon_neg(tr): 0.380  loss_kld(tr): 44.421  loss_triplet(tr): 10.652
# [00040000/00100000]  loss(tr): 153.251  loss_recon_src(tr): 0.429  loss_recon_tar(tr): 0.328  loss_recon_neg(tr): 0.380  loss_kld(tr): 45.813  loss_triplet(tr): 10.725  valid_ratio(va): 1.000  similarity(va): 0.149
# [00041000/00100000]  loss(tr): 150.449  loss_recon_src(tr): 0.435  loss_recon_tar(tr): 0.305  loss_recon_neg(tr): 0.378  loss_kld(tr): 43.591  loss_triplet(tr): 10.667
# [00042000/00100000]  loss(tr): 153.302  loss_recon_src(tr): 0.447  loss_recon_tar(tr): 0.312  loss_recon_neg(tr): 0.367  loss_kld(tr): 48.222  loss_triplet(tr): 10.489
# [00043000/00100000]  loss(tr): 151.661  loss_recon_src(tr): 0.439  loss_recon_tar(tr): 0.308  loss_recon_neg(tr): 0.393  loss_kld(tr): 46.135  loss_triplet(tr): 10.534
# [00044000/00100000]  loss(tr): 150.657  loss_recon_src(tr): 0.430  loss_recon_tar(tr): 0.298  loss_recon_neg(tr): 0.355  loss_kld(tr): 44.197  loss_triplet(tr): 10.628
# [00045000/00100000]  loss(tr): 142.867  loss_recon_src(tr): 0.438  loss_recon_tar(tr): 0.310  loss_recon_neg(tr): 0.374  loss_kld(tr): 48.113  loss_triplet(tr): 9.457
# [00046000/00100000]  loss(tr): 161.392  loss_recon_src(tr): 0.434  loss_recon_tar(tr): 0.315  loss_recon_neg(tr): 0.388  loss_kld(tr): 45.146  loss_triplet(tr): 11.606
# [00047000/00100000]  loss(tr): 142.225  loss_recon_src(tr): 0.440  loss_recon_tar(tr): 0.300  loss_recon_neg(tr): 0.399  loss_kld(tr): 42.236  loss_triplet(tr): 9.980
# [00048000/00100000]  loss(tr): 163.391  loss_recon_src(tr): 0.420  loss_recon_tar(tr): 0.313  loss_recon_neg(tr): 0.414  loss_kld(tr): 45.096  loss_triplet(tr): 11.810
# [00049000/00100000]  loss(tr): 145.831  loss_recon_src(tr): 0.443  loss_recon_tar(tr): 0.321  loss_recon_neg(tr): 0.360  loss_kld(tr): 47.583  loss_triplet(tr): 9.806
# [00050000/00100000]  loss(tr): 147.330  loss_recon_src(tr): 0.419  loss_recon_tar(tr): 0.295  loss_recon_neg(tr): 0.396  loss_kld(tr): 46.938  loss_triplet(tr): 10.021  valid_ratio(va): 1.000  similarity(va): 0.149
# [00051000/00100000]  loss(tr): 148.378  loss_recon_src(tr): 0.430  loss_recon_tar(tr): 0.299  loss_recon_neg(tr): 0.360  loss_kld(tr): 46.959  loss_triplet(tr): 10.124
# [00052000/00100000]  loss(tr): 151.844  loss_recon_src(tr): 0.419  loss_recon_tar(tr): 0.304  loss_recon_neg(tr): 0.370  loss_kld(tr): 41.749  loss_triplet(tr): 10.991
# [00053000/00100000]  loss(tr): 147.244  loss_recon_src(tr): 0.428  loss_recon_tar(tr): 0.313  loss_recon_neg(tr): 0.373  loss_kld(tr): 46.242  loss_triplet(tr): 10.082
# [00054000/00100000]  loss(tr): 140.960  loss_recon_src(tr): 0.433  loss_recon_tar(tr): 0.309  loss_recon_neg(tr): 0.387  loss_kld(tr): 48.423  loss_triplet(tr): 9.235
# [00055000/00100000]  loss(tr): 150.295  loss_recon_src(tr): 0.431  loss_recon_tar(tr): 0.290  loss_recon_neg(tr): 0.365  loss_kld(tr): 44.914  loss_triplet(tr): 10.520
# [00056000/00100000]  loss(tr): 144.211  loss_recon_src(tr): 0.423  loss_recon_tar(tr): 0.290  loss_recon_neg(tr): 0.358  loss_kld(tr): 49.141  loss_triplet(tr): 9.489
# [00057000/00100000]  loss(tr): 168.811  loss_recon_src(tr): 0.404  loss_recon_tar(tr): 0.286  loss_recon_neg(tr): 0.376  loss_kld(tr): 48.741  loss_triplet(tr): 11.989
# [00058000/00100000]  loss(tr): 163.733  loss_recon_src(tr): 0.425  loss_recon_tar(tr): 0.294  loss_recon_neg(tr): 0.359  loss_kld(tr): 48.294  loss_triplet(tr): 11.526
# [00059000/00100000]  loss(tr): 145.849  loss_recon_src(tr): 0.423  loss_recon_tar(tr): 0.299  loss_recon_neg(tr): 0.364  loss_kld(tr): 44.960  loss_triplet(tr): 10.071
# [00060000/00100000]  loss(tr): 152.543  loss_recon_src(tr): 0.425  loss_recon_tar(tr): 0.296  loss_recon_neg(tr): 0.378  loss_kld(tr): 46.048  loss_triplet(tr): 10.631  valid_ratio(va): 1.000  similarity(va): 0.149
# [00061000/00100000]  loss(tr): 165.102  loss_recon_src(tr): 0.406  loss_recon_tar(tr): 0.311  loss_recon_neg(tr): 0.382  loss_kld(tr): 43.997  loss_triplet(tr): 12.092
# [00062000/00100000]  loss(tr): 153.333  loss_recon_src(tr): 0.431  loss_recon_tar(tr): 0.282  loss_recon_neg(tr): 0.369  loss_kld(tr): 42.820  loss_triplet(tr): 11.033
# [00063000/00100000]  loss(tr): 151.556  loss_recon_src(tr): 0.437  loss_recon_tar(tr): 0.296  loss_recon_neg(tr): 0.385  loss_kld(tr): 47.016  loss_triplet(tr): 10.435
# [00064000/00100000]  loss(tr): 146.327  loss_recon_src(tr): 0.451  loss_recon_tar(tr): 0.312  loss_recon_neg(tr): 0.339  loss_kld(tr): 46.236  loss_triplet(tr): 9.991
# [00065000/00100000]  loss(tr): 164.563  loss_recon_src(tr): 0.444  loss_recon_tar(tr): 0.317  loss_recon_neg(tr): 0.362  loss_kld(tr): 47.038  loss_triplet(tr): 11.734
# [00066000/00100000]  loss(tr): 155.188  loss_recon_src(tr): 0.423  loss_recon_tar(tr): 0.297  loss_recon_neg(tr): 0.365  loss_kld(tr): 47.381  loss_triplet(tr): 10.763
# [00067000/00100000]  loss(tr): 153.988  loss_recon_src(tr): 0.436  loss_recon_tar(tr): 0.292  loss_recon_neg(tr): 0.359  loss_kld(tr): 48.100  loss_triplet(tr): 10.571
# [00068000/00100000]  loss(tr): 155.414  loss_recon_src(tr): 0.433  loss_recon_tar(tr): 0.292  loss_recon_neg(tr): 0.361  loss_kld(tr): 47.852  loss_triplet(tr): 10.738
# [00069000/00100000]  loss(tr): 159.150  loss_recon_src(tr): 0.414  loss_recon_tar(tr): 0.300  loss_recon_neg(tr): 0.363  loss_kld(tr): 46.010  loss_triplet(tr): 11.296
# [00070000/00100000]  loss(tr): 136.887  loss_recon_src(tr): 0.431  loss_recon_tar(tr): 0.308  loss_recon_neg(tr): 0.354  loss_kld(tr): 48.380  loss_triplet(tr): 8.833  valid_ratio(va): 1.000  similarity(va): 0.149
# [00071000/00100000]  loss(tr): 159.633  loss_recon_src(tr): 0.408  loss_recon_tar(tr): 0.290  loss_recon_neg(tr): 0.379  loss_kld(tr): 48.143  loss_triplet(tr): 11.131
# [00072000/00100000]  loss(tr): 148.105  loss_recon_src(tr): 0.427  loss_recon_tar(tr): 0.308  loss_recon_neg(tr): 0.373  loss_kld(tr): 47.971  loss_triplet(tr): 9.995
# [00073000/00100000]  loss(tr): 160.054  loss_recon_src(tr): 0.436  loss_recon_tar(tr): 0.298  loss_recon_neg(tr): 0.378  loss_kld(tr): 44.922  loss_triplet(tr): 11.495
# [00074000/00100000]  loss(tr): 165.209  loss_recon_src(tr): 0.435  loss_recon_tar(tr): 0.314  loss_recon_neg(tr): 0.365  loss_kld(tr): 45.518  loss_triplet(tr): 11.951
# [00075000/00100000]  loss(tr): 159.939  loss_recon_src(tr): 0.401  loss_recon_tar(tr): 0.301  loss_recon_neg(tr): 0.356  loss_kld(tr): 49.002  loss_triplet(tr): 11.076
# [00076000/00100000]  loss(tr): 160.641  loss_recon_src(tr): 0.410  loss_recon_tar(tr): 0.293  loss_recon_neg(tr): 0.363  loss_kld(tr): 43.056  loss_triplet(tr): 11.741
# [00077000/00100000]  loss(tr): 148.609  loss_recon_src(tr): 0.413  loss_recon_tar(tr): 0.289  loss_recon_neg(tr): 0.374  loss_kld(tr): 47.760  loss_triplet(tr): 10.067
# [00078000/00100000]  loss(tr): 142.795  loss_recon_src(tr): 0.415  loss_recon_tar(tr): 0.297  loss_recon_neg(tr): 0.364  loss_kld(tr): 45.816  loss_triplet(tr): 9.680
# [00079000/00100000]  loss(tr): 153.107  loss_recon_src(tr): 0.425  loss_recon_tar(tr): 0.293  loss_recon_neg(tr): 0.349  loss_kld(tr): 45.618  loss_triplet(tr): 10.731
# [00080000/00100000]  loss(tr): 144.858  loss_recon_src(tr): 0.412  loss_recon_tar(tr): 0.294  loss_recon_neg(tr): 0.357  loss_kld(tr): 49.131  loss_triplet(tr): 9.555  valid_ratio(va): 1.000  similarity(va): 0.150
# [00081000/00100000]  loss(tr): 156.648  loss_recon_src(tr): 0.429  loss_recon_tar(tr): 0.284  loss_recon_neg(tr): 0.364  loss_kld(tr): 48.276  loss_triplet(tr): 10.819
# [00082000/00100000]  loss(tr): 137.506  loss_recon_src(tr): 0.429  loss_recon_tar(tr): 0.315  loss_recon_neg(tr): 0.367  loss_kld(tr): 46.534  loss_triplet(tr): 9.079
# [00083000/00100000]  loss(tr): 162.520  loss_recon_src(tr): 0.427  loss_recon_tar(tr): 0.285  loss_recon_neg(tr): 0.376  loss_kld(tr): 49.383  loss_triplet(tr): 11.296
# [00084000/00100000]  loss(tr): 148.876  loss_recon_src(tr): 0.439  loss_recon_tar(tr): 0.302  loss_recon_neg(tr): 0.379  loss_kld(tr): 46.337  loss_triplet(tr): 10.235
# [00085000/00100000]  loss(tr): 155.156  loss_recon_src(tr): 0.416  loss_recon_tar(tr): 0.310  loss_recon_neg(tr): 0.348  loss_kld(tr): 46.938  loss_triplet(tr): 10.804
# [00086000/00100000]  loss(tr): 171.990  loss_recon_src(tr): 0.421  loss_recon_tar(tr): 0.296  loss_recon_neg(tr): 0.356  loss_kld(tr): 47.889  loss_triplet(tr): 12.392
# [00087000/00100000]  loss(tr): 133.538  loss_recon_src(tr): 0.423  loss_recon_tar(tr): 0.283  loss_recon_neg(tr): 0.345  loss_kld(tr): 48.452  loss_triplet(tr): 8.491
# [00088000/00100000]  loss(tr): 148.307  loss_recon_src(tr): 0.398  loss_recon_tar(tr): 0.277  loss_recon_neg(tr): 0.351  loss_kld(tr): 48.428  loss_triplet(tr): 9.971
# [00089000/00100000]  loss(tr): 154.720  loss_recon_src(tr): 0.446  loss_recon_tar(tr): 0.303  loss_recon_neg(tr): 0.342  loss_kld(tr): 46.055  loss_triplet(tr): 10.849
# [00090000/00100000]  loss(tr): 158.012  loss_recon_src(tr): 0.414  loss_recon_tar(tr): 0.287  loss_recon_neg(tr): 0.352  loss_kld(tr): 44.863  loss_triplet(tr): 11.297  valid_ratio(va): 1.000  similarity(va): 0.149
# [00091000/00100000]  loss(tr): 154.118  loss_recon_src(tr): 0.421  loss_recon_tar(tr): 0.285  loss_recon_neg(tr): 0.358  loss_kld(tr): 42.984  loss_triplet(tr): 11.096
# [00092000/00100000]  loss(tr): 141.384  loss_recon_src(tr): 0.421  loss_recon_tar(tr): 0.312  loss_recon_neg(tr): 0.353  loss_kld(tr): 48.945  loss_triplet(tr): 9.226
# [00093000/00100000]  loss(tr): 149.620  loss_recon_src(tr): 0.401  loss_recon_tar(tr): 0.287  loss_recon_neg(tr): 0.346  loss_kld(tr): 48.812  loss_triplet(tr): 10.064
# [00094000/00100000]  loss(tr): 144.677  loss_recon_src(tr): 0.434  loss_recon_tar(tr): 0.282  loss_recon_neg(tr): 0.321  loss_kld(tr): 47.261  loss_triplet(tr): 9.724
# [00095000/00100000]  loss(tr): 152.181  loss_recon_src(tr): 0.419  loss_recon_tar(tr): 0.307  loss_recon_neg(tr): 0.344  loss_kld(tr): 45.777  loss_triplet(tr): 10.623
# [00096000/00100000]  loss(tr): 160.775  loss_recon_src(tr): 0.440  loss_recon_tar(tr): 0.302  loss_recon_neg(tr): 0.351  loss_kld(tr): 44.734  loss_triplet(tr): 11.586
# [00097000/00100000]  loss(tr): 156.762  loss_recon_src(tr): 0.428  loss_recon_tar(tr): 0.307  loss_recon_neg(tr): 0.349  loss_kld(tr): 49.446  loss_triplet(tr): 10.714
# [00098000/00100000]  loss(tr): 154.959  loss_recon_src(tr): 0.406  loss_recon_tar(tr): 0.279  loss_recon_neg(tr): 0.328  loss_kld(tr): 49.000  loss_triplet(tr): 10.579
# [00099000/00100000]  loss(tr): 142.520  loss_recon_src(tr): 0.414  loss_recon_tar(tr): 0.289  loss_recon_neg(tr): 0.355  loss_kld(tr): 49.851  loss_triplet(tr): 9.249
# [00100000/00100000]  loss(tr): 152.915  loss_recon_src(tr): 0.428  loss_recon_tar(tr): 0.303  loss_recon_neg(tr): 0.335  loss_kld(tr): 49.562  loss_triplet(tr): 10.318  valid_ratio(va): 1.000  similarity(va): 0.149

# %% [markdown]
# ## 9. Visualize for loss analysis

# %%
fig, axes = plt.subplots(4,1,figsize=(8,8))

axes[0].plot(df_history.loc[:,"LOSS_TOTAL"], label="Total loss")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_SOURCE"], label="Recon. loss (src)")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_TARGET"], label="Recon. loss (tar)")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_NEGATIVE"], label="Recon. loss (neg)")
axes[2].plot(df_history.loc[:,"LOSS_KL_DIVERGENCE"], label="KLD loss (src,tar)")
axes[3].plot(df_history.loc[:,"LOSS_TRIPLET"], label="Triplet loss (src,tar,neg)")

axes[3].set_xlabel("Iteration")
for ax in axes:
    ax.legend(loc='best')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,1,figsize=(8,4))

axes[0].plot(df_history_valid.loc[:,"VALID_RATIO"], label="Validity")
axes[1].plot(df_history_valid.loc[:,"AVERAGE_SIMILARITY"], label="Tanimoto coeff.")

axes[1].set_xlabel("Iteration")
for ax in axes:
    ax.legend(loc='best')

plt.tight_layout()
plt.show()
