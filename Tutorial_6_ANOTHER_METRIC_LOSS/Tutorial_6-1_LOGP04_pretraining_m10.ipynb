# %% [markdown]
# # Tutorial - Step1 : MTMR pretraining with Metric learning

# %% [markdown]
# ## 1. Import requirements

# %%
import os
import sys
import pandas as pd
import torch
import time
import matplotlib.pyplot as plt

# %%
sys.path = [os.path.abspath(os.path.join(os.getcwd(), os.pardir))] + sys.path

# %%
from MTMR.dataset import TrainingSmilesDataset, ValidationSmilesDataset
from vae_triplet import SmilesAutoencoder

# %% [markdown]
# ## 2. Configure GPU (if available)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# ## 3. Specify a target property

# %%
PROPERTY_NAME = "logp04"

# %% [markdown]
# ## 4. Set directories (for inputs and outputs)

# %%
input_dir = os.path.abspath(os.path.join(os.pardir, "DATA", PROPERTY_NAME))

# %%
output_dir = f"outputs_6-1_{PROPERTY_NAME.upper()}_pretraining_m10"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

# %% [markdown]
# ## 5. Set file names

# %%
filepath_train = os.path.join(input_dir, "rdkit_train_triplet.txt")
filepath_valid = os.path.join(input_dir, "rdkit_valid.txt")

# %%
filepath_char2idx      = os.path.join(output_dir, "char2idx.csv")
filepath_configs       = os.path.join(output_dir, "configs.csv")
filepath_checkpoint    = os.path.join(output_dir, "checkpoints.pt")
filepath_history       = os.path.join(output_dir, "history.csv")
filepath_history_valid = os.path.join(output_dir, "history_valid.csv")

# %% [markdown]
# ## 6. Load datasets (for training and validation)

# %%
dataset = TrainingSmilesDataset(filepath_train, device=device)
dataset.save_char2idx(filepath_char2idx)
dataset_valid = ValidationSmilesDataset(filepath_valid, filepath_char2idx, device=device)

# %% [markdown]
# ## 7. Initialize a generator of MTMR

# %%
## Model configuration
model_configs = {"hidden_size":128,
                 "latent_size":128,
                 "num_layers" :2,
                 "vocab_size" :dataset.vocab_size,
                 "sos_idx"    :dataset.sos_idx,
                 "eos_idx"    :dataset.eos_idx,
                 "pad_idx"    :dataset.pad_idx,
                 "device"     :device
                }

## Model initialization
generator = SmilesAutoencoder(**model_configs)

## Configuration save
generator.save_config(filepath_configs)

# %% [markdown]
# ## 8. Train

# %%
df_history, df_history_valid = generator.fit(dataset,
                                             validation_dataset=dataset_valid,
                                             margin=10.,
                                             checkpoint_filepath=filepath_checkpoint)

df_history.to_csv(filepath_history, index=False)
df_history_valid.to_csv(filepath_history_valid, index=False)
# Out:
# [00000000/00100000]  loss(tr): 101.824  loss_recon_src(tr): 3.353  loss_recon_tar(tr): 3.340  loss_recon_neg(tr): 3.347  loss_kld(tr): 1.915  loss_triplet(tr): 9.824  valid_ratio(va): 0.155  similarity(va): 0.004
# [00001000/00100000]  loss(tr): 76.848  loss_recon_src(tr): 0.672  loss_recon_tar(tr): 0.599  loss_recon_neg(tr): 0.662  loss_kld(tr): 16.160  loss_triplet(tr): 6.036
# [00002000/00100000]  loss(tr): 66.401  loss_recon_src(tr): 0.589  loss_recon_tar(tr): 0.560  loss_recon_neg(tr): 0.587  loss_kld(tr): 15.061  loss_triplet(tr): 5.105
# [00003000/00100000]  loss(tr): 60.651  loss_recon_src(tr): 0.562  loss_recon_tar(tr): 0.499  loss_recon_neg(tr): 0.560  loss_kld(tr): 16.837  loss_triplet(tr): 4.354
# [00004000/00100000]  loss(tr): 72.882  loss_recon_src(tr): 0.549  loss_recon_tar(tr): 0.480  loss_recon_neg(tr): 0.549  loss_kld(tr): 17.568  loss_triplet(tr): 5.505
# [00005000/00100000]  loss(tr): 68.309  loss_recon_src(tr): 0.519  loss_recon_tar(tr): 0.459  loss_recon_neg(tr): 0.556  loss_kld(tr): 17.289  loss_triplet(tr): 5.076
# [00006000/00100000]  loss(tr): 53.520  loss_recon_src(tr): 0.526  loss_recon_tar(tr): 0.464  loss_recon_neg(tr): 0.518  loss_kld(tr): 18.507  loss_triplet(tr): 3.476
# [00007000/00100000]  loss(tr): 57.297  loss_recon_src(tr): 0.538  loss_recon_tar(tr): 0.497  loss_recon_neg(tr): 0.513  loss_kld(tr): 17.566  loss_triplet(tr): 3.947
# [00008000/00100000]  loss(tr): 67.772  loss_recon_src(tr): 0.518  loss_recon_tar(tr): 0.458  loss_recon_neg(tr): 0.497  loss_kld(tr): 16.227  loss_triplet(tr): 5.130
# [00009000/00100000]  loss(tr): 71.994  loss_recon_src(tr): 0.508  loss_recon_tar(tr): 0.452  loss_recon_neg(tr): 0.539  loss_kld(tr): 17.527  loss_triplet(tr): 5.422
# [00010000/00100000]  loss(tr): 56.133  loss_recon_src(tr): 0.524  loss_recon_tar(tr): 0.452  loss_recon_neg(tr): 0.508  loss_kld(tr): 16.653  loss_triplet(tr): 3.923  valid_ratio(va): 1.000  similarity(va): 0.121
# [00011000/00100000]  loss(tr): 73.016  loss_recon_src(tr): 0.491  loss_recon_tar(tr): 0.428  loss_recon_neg(tr): 0.508  loss_kld(tr): 17.128  loss_triplet(tr): 5.565
# [00012000/00100000]  loss(tr): 70.445  loss_recon_src(tr): 0.497  loss_recon_tar(tr): 0.466  loss_recon_neg(tr): 0.494  loss_kld(tr): 17.499  loss_triplet(tr): 5.270
# [00013000/00100000]  loss(tr): 72.061  loss_recon_src(tr): 0.508  loss_recon_tar(tr): 0.450  loss_recon_neg(tr): 0.505  loss_kld(tr): 17.602  loss_triplet(tr): 5.421
# [00014000/00100000]  loss(tr): 58.319  loss_recon_src(tr): 0.482  loss_recon_tar(tr): 0.455  loss_recon_neg(tr): 0.487  loss_kld(tr): 19.425  loss_triplet(tr): 3.866
# [00015000/00100000]  loss(tr): 61.067  loss_recon_src(tr): 0.495  loss_recon_tar(tr): 0.444  loss_recon_neg(tr): 0.482  loss_kld(tr): 18.742  loss_triplet(tr): 4.209
# [00016000/00100000]  loss(tr): 65.283  loss_recon_src(tr): 0.493  loss_recon_tar(tr): 0.443  loss_recon_neg(tr): 0.485  loss_kld(tr): 18.529  loss_triplet(tr): 4.652
# [00017000/00100000]  loss(tr): 68.273  loss_recon_src(tr): 0.498  loss_recon_tar(tr): 0.446  loss_recon_neg(tr): 0.461  loss_kld(tr): 18.227  loss_triplet(tr): 4.981
# [00018000/00100000]  loss(tr): 65.631  loss_recon_src(tr): 0.501  loss_recon_tar(tr): 0.455  loss_recon_neg(tr): 0.483  loss_kld(tr): 19.457  loss_triplet(tr): 4.593
# [00019000/00100000]  loss(tr): 63.655  loss_recon_src(tr): 0.480  loss_recon_tar(tr): 0.422  loss_recon_neg(tr): 0.483  loss_kld(tr): 18.182  loss_triplet(tr): 4.524
# [00020000/00100000]  loss(tr): 64.749  loss_recon_src(tr): 0.472  loss_recon_tar(tr): 0.419  loss_recon_neg(tr): 0.472  loss_kld(tr): 18.440  loss_triplet(tr): 4.608  valid_ratio(va): 1.000  similarity(va): 0.121
# [00021000/00100000]  loss(tr): 64.961  loss_recon_src(tr): 0.477  loss_recon_tar(tr): 0.430  loss_recon_neg(tr): 0.487  loss_kld(tr): 19.019  loss_triplet(tr): 4.571
# [00022000/00100000]  loss(tr): 49.337  loss_recon_src(tr): 0.459  loss_recon_tar(tr): 0.429  loss_recon_neg(tr): 0.459  loss_kld(tr): 19.414  loss_triplet(tr): 2.970
# [00023000/00100000]  loss(tr): 58.315  loss_recon_src(tr): 0.476  loss_recon_tar(tr): 0.443  loss_recon_neg(tr): 0.465  loss_kld(tr): 19.110  loss_triplet(tr): 3.897
# [00024000/00100000]  loss(tr): 68.248  loss_recon_src(tr): 0.480  loss_recon_tar(tr): 0.439  loss_recon_neg(tr): 0.486  loss_kld(tr): 18.660  loss_triplet(tr): 4.935
# [00025000/00100000]  loss(tr): 58.248  loss_recon_src(tr): 0.493  loss_recon_tar(tr): 0.425  loss_recon_neg(tr): 0.485  loss_kld(tr): 18.278  loss_triplet(tr): 3.974
# [00026000/00100000]  loss(tr): 57.574  loss_recon_src(tr): 0.465  loss_recon_tar(tr): 0.428  loss_recon_neg(tr): 0.482  loss_kld(tr): 19.524  loss_triplet(tr): 3.782
# [00027000/00100000]  loss(tr): 61.565  loss_recon_src(tr): 0.456  loss_recon_tar(tr): 0.426  loss_recon_neg(tr): 0.459  loss_kld(tr): 19.221  loss_triplet(tr): 4.212
# [00028000/00100000]  loss(tr): 74.765  loss_recon_src(tr): 0.469  loss_recon_tar(tr): 0.420  loss_recon_neg(tr): 0.463  loss_kld(tr): 18.797  loss_triplet(tr): 5.574
# [00029000/00100000]  loss(tr): 66.010  loss_recon_src(tr): 0.473  loss_recon_tar(tr): 0.422  loss_recon_neg(tr): 0.474  loss_kld(tr): 20.295  loss_triplet(tr): 4.549
# [00030000/00100000]  loss(tr): 57.154  loss_recon_src(tr): 0.483  loss_recon_tar(tr): 0.445  loss_recon_neg(tr): 0.456  loss_kld(tr): 18.352  loss_triplet(tr): 3.857  valid_ratio(va): 1.000  similarity(va): 0.123
# [00031000/00100000]  loss(tr): 67.999  loss_recon_src(tr): 0.457  loss_recon_tar(tr): 0.436  loss_recon_neg(tr): 0.457  loss_kld(tr): 18.716  loss_triplet(tr): 4.906
# [00032000/00100000]  loss(tr): 61.383  loss_recon_src(tr): 0.454  loss_recon_tar(tr): 0.417  loss_recon_neg(tr): 0.458  loss_kld(tr): 19.134  loss_triplet(tr): 4.203
# [00033000/00100000]  loss(tr): 68.653  loss_recon_src(tr): 0.456  loss_recon_tar(tr): 0.404  loss_recon_neg(tr): 0.466  loss_kld(tr): 18.931  loss_triplet(tr): 4.950
# [00034000/00100000]  loss(tr): 57.172  loss_recon_src(tr): 0.460  loss_recon_tar(tr): 0.412  loss_recon_neg(tr): 0.469  loss_kld(tr): 19.360  loss_triplet(tr): 3.759
# [00035000/00100000]  loss(tr): 57.526  loss_recon_src(tr): 0.476  loss_recon_tar(tr): 0.432  loss_recon_neg(tr): 0.486  loss_kld(tr): 19.145  loss_triplet(tr): 3.815
# [00036000/00100000]  loss(tr): 60.304  loss_recon_src(tr): 0.451  loss_recon_tar(tr): 0.419  loss_recon_neg(tr): 0.453  loss_kld(tr): 18.564  loss_triplet(tr): 4.152
# [00037000/00100000]  loss(tr): 69.423  loss_recon_src(tr): 0.460  loss_recon_tar(tr): 0.417  loss_recon_neg(tr): 0.467  loss_kld(tr): 18.047  loss_triplet(tr): 5.115
# [00038000/00100000]  loss(tr): 60.870  loss_recon_src(tr): 0.470  loss_recon_tar(tr): 0.431  loss_recon_neg(tr): 0.455  loss_kld(tr): 18.306  loss_triplet(tr): 4.234
# [00039000/00100000]  loss(tr): 65.261  loss_recon_src(tr): 0.469  loss_recon_tar(tr): 0.434  loss_recon_neg(tr): 0.460  loss_kld(tr): 17.176  loss_triplet(tr): 4.786
# [00040000/00100000]  loss(tr): 60.544  loss_recon_src(tr): 0.444  loss_recon_tar(tr): 0.413  loss_recon_neg(tr): 0.487  loss_kld(tr): 18.565  loss_triplet(tr): 4.175  valid_ratio(va): 1.000  similarity(va): 0.124
# [00041000/00100000]  loss(tr): 54.806  loss_recon_src(tr): 0.460  loss_recon_tar(tr): 0.406  loss_recon_neg(tr): 0.475  loss_kld(tr): 19.382  loss_triplet(tr): 3.520
# [00042000/00100000]  loss(tr): 59.049  loss_recon_src(tr): 0.444  loss_recon_tar(tr): 0.398  loss_recon_neg(tr): 0.446  loss_kld(tr): 19.329  loss_triplet(tr): 3.950
# [00043000/00100000]  loss(tr): 63.327  loss_recon_src(tr): 0.445  loss_recon_tar(tr): 0.406  loss_recon_neg(tr): 0.462  loss_kld(tr): 17.255  loss_triplet(tr): 4.585
# [00044000/00100000]  loss(tr): 68.339  loss_recon_src(tr): 0.436  loss_recon_tar(tr): 0.416  loss_recon_neg(tr): 0.454  loss_kld(tr): 18.449  loss_triplet(tr): 4.967
# [00045000/00100000]  loss(tr): 56.372  loss_recon_src(tr): 0.446  loss_recon_tar(tr): 0.409  loss_recon_neg(tr): 0.456  loss_kld(tr): 19.758  loss_triplet(tr): 3.639
# [00046000/00100000]  loss(tr): 56.766  loss_recon_src(tr): 0.465  loss_recon_tar(tr): 0.405  loss_recon_neg(tr): 0.479  loss_kld(tr): 18.835  loss_triplet(tr): 3.770
# [00047000/00100000]  loss(tr): 65.463  loss_recon_src(tr): 0.443  loss_recon_tar(tr): 0.403  loss_recon_neg(tr): 0.439  loss_kld(tr): 17.678  loss_triplet(tr): 4.757
# [00048000/00100000]  loss(tr): 67.535  loss_recon_src(tr): 0.450  loss_recon_tar(tr): 0.423  loss_recon_neg(tr): 0.419  loss_kld(tr): 18.814  loss_triplet(tr): 4.851
# [00049000/00100000]  loss(tr): 66.549  loss_recon_src(tr): 0.465  loss_recon_tar(tr): 0.414  loss_recon_neg(tr): 0.425  loss_kld(tr): 19.124  loss_triplet(tr): 4.721
# [00050000/00100000]  loss(tr): 55.786  loss_recon_src(tr): 0.462  loss_recon_tar(tr): 0.406  loss_recon_neg(tr): 0.446  loss_kld(tr): 18.615  loss_triplet(tr): 3.695  valid_ratio(va): 1.000  similarity(va): 0.123
# [00051000/00100000]  loss(tr): 50.348  loss_recon_src(tr): 0.446  loss_recon_tar(tr): 0.417  loss_recon_neg(tr): 0.458  loss_kld(tr): 17.384  loss_triplet(tr): 3.274
# [00052000/00100000]  loss(tr): 71.585  loss_recon_src(tr): 0.466  loss_recon_tar(tr): 0.410  loss_recon_neg(tr): 0.460  loss_kld(tr): 19.113  loss_triplet(tr): 5.225
# [00053000/00100000]  loss(tr): 54.554  loss_recon_src(tr): 0.451  loss_recon_tar(tr): 0.412  loss_recon_neg(tr): 0.455  loss_kld(tr): 19.704  loss_triplet(tr): 3.463
# [00054000/00100000]  loss(tr): 59.570  loss_recon_src(tr): 0.449  loss_recon_tar(tr): 0.414  loss_recon_neg(tr): 0.440  loss_kld(tr): 18.477  loss_triplet(tr): 4.088
# [00055000/00100000]  loss(tr): 58.337  loss_recon_src(tr): 0.441  loss_recon_tar(tr): 0.399  loss_recon_neg(tr): 0.440  loss_kld(tr): 18.326  loss_triplet(tr): 3.980
# [00056000/00100000]  loss(tr): 60.803  loss_recon_src(tr): 0.440  loss_recon_tar(tr): 0.420  loss_recon_neg(tr): 0.452  loss_kld(tr): 18.472  loss_triplet(tr): 4.211
# [00057000/00100000]  loss(tr): 69.093  loss_recon_src(tr): 0.453  loss_recon_tar(tr): 0.418  loss_recon_neg(tr): 0.456  loss_kld(tr): 19.962  loss_triplet(tr): 4.891
# [00058000/00100000]  loss(tr): 61.545  loss_recon_src(tr): 0.442  loss_recon_tar(tr): 0.398  loss_recon_neg(tr): 0.453  loss_kld(tr): 17.984  loss_triplet(tr): 4.334
# [00059000/00100000]  loss(tr): 62.490  loss_recon_src(tr): 0.455  loss_recon_tar(tr): 0.418  loss_recon_neg(tr): 0.444  loss_kld(tr): 18.121  loss_triplet(tr): 4.415
# [00060000/00100000]  loss(tr): 65.320  loss_recon_src(tr): 0.438  loss_recon_tar(tr): 0.399  loss_recon_neg(tr): 0.473  loss_kld(tr): 17.672  loss_triplet(tr): 4.743  valid_ratio(va): 1.000  similarity(va): 0.123
# [00061000/00100000]  loss(tr): 67.589  loss_recon_src(tr): 0.445  loss_recon_tar(tr): 0.407  loss_recon_neg(tr): 0.452  loss_kld(tr): 18.518  loss_triplet(tr): 4.885
# [00062000/00100000]  loss(tr): 62.321  loss_recon_src(tr): 0.444  loss_recon_tar(tr): 0.408  loss_recon_neg(tr): 0.468  loss_kld(tr): 19.995  loss_triplet(tr): 4.210
# [00063000/00100000]  loss(tr): 62.137  loss_recon_src(tr): 0.419  loss_recon_tar(tr): 0.392  loss_recon_neg(tr): 0.453  loss_kld(tr): 18.737  loss_triplet(tr): 4.319
# [00064000/00100000]  loss(tr): 61.918  loss_recon_src(tr): 0.460  loss_recon_tar(tr): 0.398  loss_recon_neg(tr): 0.437  loss_kld(tr): 18.883  loss_triplet(tr): 4.282
# [00065000/00100000]  loss(tr): 57.148  loss_recon_src(tr): 0.450  loss_recon_tar(tr): 0.403  loss_recon_neg(tr): 0.470  loss_kld(tr): 19.096  loss_triplet(tr): 3.783
# [00066000/00100000]  loss(tr): 67.295  loss_recon_src(tr): 0.456  loss_recon_tar(tr): 0.408  loss_recon_neg(tr): 0.458  loss_kld(tr): 18.504  loss_triplet(tr): 4.857
# [00067000/00100000]  loss(tr): 47.890  loss_recon_src(tr): 0.444  loss_recon_tar(tr): 0.409  loss_recon_neg(tr): 0.466  loss_kld(tr): 19.191  loss_triplet(tr): 2.848
# [00068000/00100000]  loss(tr): 63.790  loss_recon_src(tr): 0.432  loss_recon_tar(tr): 0.393  loss_recon_neg(tr): 0.463  loss_kld(tr): 18.534  loss_triplet(tr): 4.504
# [00069000/00100000]  loss(tr): 61.816  loss_recon_src(tr): 0.433  loss_recon_tar(tr): 0.392  loss_recon_neg(tr): 0.457  loss_kld(tr): 18.621  loss_triplet(tr): 4.298
# [00070000/00100000]  loss(tr): 63.786  loss_recon_src(tr): 0.466  loss_recon_tar(tr): 0.412  loss_recon_neg(tr): 0.425  loss_kld(tr): 18.836  loss_triplet(tr): 4.473  valid_ratio(va): 1.000  similarity(va): 0.123
# [00071000/00100000]  loss(tr): 52.092  loss_recon_src(tr): 0.441  loss_recon_tar(tr): 0.394  loss_recon_neg(tr): 0.472  loss_kld(tr): 18.566  loss_triplet(tr): 3.331
# [00072000/00100000]  loss(tr): 59.174  loss_recon_src(tr): 0.435  loss_recon_tar(tr): 0.410  loss_recon_neg(tr): 0.443  loss_kld(tr): 19.494  loss_triplet(tr): 3.947
# [00073000/00100000]  loss(tr): 67.740  loss_recon_src(tr): 0.434  loss_recon_tar(tr): 0.411  loss_recon_neg(tr): 0.447  loss_kld(tr): 17.446  loss_triplet(tr): 5.008
# [00074000/00100000]  loss(tr): 66.172  loss_recon_src(tr): 0.456  loss_recon_tar(tr): 0.388  loss_recon_neg(tr): 0.445  loss_kld(tr): 18.737  loss_triplet(tr): 4.722
# [00075000/00100000]  loss(tr): 66.031  loss_recon_src(tr): 0.438  loss_recon_tar(tr): 0.380  loss_recon_neg(tr): 0.454  loss_kld(tr): 19.566  loss_triplet(tr): 4.625
# [00076000/00100000]  loss(tr): 60.554  loss_recon_src(tr): 0.441  loss_recon_tar(tr): 0.385  loss_recon_neg(tr): 0.442  loss_kld(tr): 19.199  loss_triplet(tr): 4.114
# [00077000/00100000]  loss(tr): 68.945  loss_recon_src(tr): 0.435  loss_recon_tar(tr): 0.405  loss_recon_neg(tr): 0.454  loss_kld(tr): 18.260  loss_triplet(tr): 5.047
# [00078000/00100000]  loss(tr): 60.179  loss_recon_src(tr): 0.429  loss_recon_tar(tr): 0.393  loss_recon_neg(tr): 0.464  loss_kld(tr): 18.292  loss_triplet(tr): 4.167
# [00079000/00100000]  loss(tr): 60.658  loss_recon_src(tr): 0.434  loss_recon_tar(tr): 0.388  loss_recon_neg(tr): 0.453  loss_kld(tr): 18.638  loss_triplet(tr): 4.181
# [00080000/00100000]  loss(tr): 69.590  loss_recon_src(tr): 0.450  loss_recon_tar(tr): 0.402  loss_recon_neg(tr): 0.433  loss_kld(tr): 18.521  loss_triplet(tr): 5.085  valid_ratio(va): 1.000  similarity(va): 0.126
# [00081000/00100000]  loss(tr): 70.330  loss_recon_src(tr): 0.437  loss_recon_tar(tr): 0.395  loss_recon_neg(tr): 0.449  loss_kld(tr): 18.015  loss_triplet(tr): 5.210
# [00082000/00100000]  loss(tr): 59.654  loss_recon_src(tr): 0.450  loss_recon_tar(tr): 0.403  loss_recon_neg(tr): 0.450  loss_kld(tr): 18.016  loss_triplet(tr): 4.142
# [00083000/00100000]  loss(tr): 62.270  loss_recon_src(tr): 0.430  loss_recon_tar(tr): 0.407  loss_recon_neg(tr): 0.447  loss_kld(tr): 17.793  loss_triplet(tr): 4.426
# [00084000/00100000]  loss(tr): 61.293  loss_recon_src(tr): 0.428  loss_recon_tar(tr): 0.394  loss_recon_neg(tr): 0.437  loss_kld(tr): 17.823  loss_triplet(tr): 4.326
# [00085000/00100000]  loss(tr): 68.303  loss_recon_src(tr): 0.447  loss_recon_tar(tr): 0.410  loss_recon_neg(tr): 0.437  loss_kld(tr): 18.632  loss_triplet(tr): 4.945
# [00086000/00100000]  loss(tr): 69.706  loss_recon_src(tr): 0.451  loss_recon_tar(tr): 0.397  loss_recon_neg(tr): 0.449  loss_kld(tr): 19.093  loss_triplet(tr): 5.040
# [00087000/00100000]  loss(tr): 71.608  loss_recon_src(tr): 0.458  loss_recon_tar(tr): 0.405  loss_recon_neg(tr): 0.450  loss_kld(tr): 17.528  loss_triplet(tr): 5.386
# [00088000/00100000]  loss(tr): 59.389  loss_recon_src(tr): 0.423  loss_recon_tar(tr): 0.404  loss_recon_neg(tr): 0.462  loss_kld(tr): 18.682  loss_triplet(tr): 4.049
# [00089000/00100000]  loss(tr): 70.171  loss_recon_src(tr): 0.437  loss_recon_tar(tr): 0.392  loss_recon_neg(tr): 0.452  loss_kld(tr): 18.489  loss_triplet(tr): 5.147
# [00090000/00100000]  loss(tr): 53.122  loss_recon_src(tr): 0.427  loss_recon_tar(tr): 0.383  loss_recon_neg(tr): 0.424  loss_kld(tr): 18.331  loss_triplet(tr): 3.459  valid_ratio(va): 1.000  similarity(va): 0.124
# [00091000/00100000]  loss(tr): 70.733  loss_recon_src(tr): 0.449  loss_recon_tar(tr): 0.403  loss_recon_neg(tr): 0.447  loss_kld(tr): 18.267  loss_triplet(tr): 5.225
# [00092000/00100000]  loss(tr): 68.497  loss_recon_src(tr): 0.444  loss_recon_tar(tr): 0.409  loss_recon_neg(tr): 0.457  loss_kld(tr): 18.662  loss_triplet(tr): 4.962
# [00093000/00100000]  loss(tr): 54.793  loss_recon_src(tr): 0.421  loss_recon_tar(tr): 0.373  loss_recon_neg(tr): 0.444  loss_kld(tr): 18.700  loss_triplet(tr): 3.588
# [00094000/00100000]  loss(tr): 68.155  loss_recon_src(tr): 0.438  loss_recon_tar(tr): 0.389  loss_recon_neg(tr): 0.447  loss_kld(tr): 17.993  loss_triplet(tr): 4.995
# [00095000/00100000]  loss(tr): 58.594  loss_recon_src(tr): 0.433  loss_recon_tar(tr): 0.387  loss_recon_neg(tr): 0.438  loss_kld(tr): 18.795  loss_triplet(tr): 3.959
# [00096000/00100000]  loss(tr): 56.603  loss_recon_src(tr): 0.448  loss_recon_tar(tr): 0.405  loss_recon_neg(tr): 0.430  loss_kld(tr): 18.799  loss_triplet(tr): 3.759
# [00097000/00100000]  loss(tr): 56.452  loss_recon_src(tr): 0.458  loss_recon_tar(tr): 0.392  loss_recon_neg(tr): 0.453  loss_kld(tr): 20.055  loss_triplet(tr): 3.618
# [00098000/00100000]  loss(tr): 67.509  loss_recon_src(tr): 0.454  loss_recon_tar(tr): 0.408  loss_recon_neg(tr): 0.454  loss_kld(tr): 18.672  loss_triplet(tr): 4.862
# [00099000/00100000]  loss(tr): 59.806  loss_recon_src(tr): 0.454  loss_recon_tar(tr): 0.405  loss_recon_neg(tr): 0.435  loss_kld(tr): 18.779  loss_triplet(tr): 4.081
# [00100000/00100000]  loss(tr): 65.863  loss_recon_src(tr): 0.431  loss_recon_tar(tr): 0.411  loss_recon_neg(tr): 0.446  loss_kld(tr): 18.079  loss_triplet(tr): 4.757  valid_ratio(va): 1.000  similarity(va): 0.122

# %% [markdown]
# ## 9. Visualize for loss analysis

# %%
fig, axes = plt.subplots(4,1,figsize=(8,8))

axes[0].plot(df_history.loc[:,"LOSS_TOTAL"], label="Total loss")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_SOURCE"], label="Recon. loss (src)")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_TARGET"], label="Recon. loss (tar)")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_NEGATIVE"], label="Recon. loss (neg)")
axes[2].plot(df_history.loc[:,"LOSS_KL_DIVERGENCE"], label="KLD loss (src,tar)")
axes[3].plot(df_history.loc[:,"LOSS_TRIPLET"], label="Triplet loss (src,tar,neg)")

axes[3].set_xlabel("Iteration")
for ax in axes:
    ax.legend(loc='best')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,1,figsize=(8,4))

axes[0].plot(df_history_valid.loc[:,"VALID_RATIO"], label="Validity")
axes[1].plot(df_history_valid.loc[:,"AVERAGE_SIMILARITY"], label="Tanimoto coeff.")

axes[1].set_xlabel("Iteration")
for ax in axes:
    ax.legend(loc='best')

plt.tight_layout()
plt.show()
