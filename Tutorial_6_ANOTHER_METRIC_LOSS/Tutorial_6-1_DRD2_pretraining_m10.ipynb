# %% [markdown]
# # Tutorial - VAE pretraining with a traditional metric loss; triplet loss

# %% [markdown]
# ## 1. Import requirements

# %%
import os
import sys
import pandas as pd
import torch
import time
import matplotlib.pyplot as plt

# %%
sys.path = [os.path.abspath(os.path.join(os.getcwd(), os.pardir))] + sys.path

# %%
from MTMR.dataset import TrainingSmilesDataset, ValidationSmilesDataset
from vae_triplet import SmilesAutoencoder

# %% [markdown]
# ## 2. Configure GPU (if available)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# ## 3. Specify a target property

# %%
PROPERTY_NAME = "drd2"

# %% [markdown]
# ## 4. Set directories (for inputs and outputs)

# %%
input_dir = os.path.abspath(os.path.join(os.pardir, "DATA", PROPERTY_NAME))

# %%
output_dir = f"outputs_6-1_{PROPERTY_NAME.upper()}_pretraining_m10"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

# %% [markdown]
# ## 5. Set file names

# %%
filepath_train = os.path.join(input_dir, "rdkit_train_triplet.txt")
filepath_valid = os.path.join(input_dir, "rdkit_valid.txt")

# %%
filepath_char2idx      = os.path.join(output_dir, "char2idx.csv")
filepath_configs       = os.path.join(output_dir, "configs.csv")
filepath_checkpoint    = os.path.join(output_dir, "checkpoints.pt")
filepath_history       = os.path.join(output_dir, "history.csv")
filepath_history_valid = os.path.join(output_dir, "history_valid.csv")

# %% [markdown]
# ## 6. Load datasets (for training and validation)

# %%
dataset = TrainingSmilesDataset(filepath_train, device=device)
dataset.save_char2idx(filepath_char2idx)
dataset_valid = ValidationSmilesDataset(filepath_valid, filepath_char2idx, device=device)

# %% [markdown]
# ## 7. Initialize a generator of MTMR

# %%
## Model configuration
model_configs = {"hidden_size":128,
                 "latent_size":128,
                 "num_layers" :2,
                 "vocab_size" :dataset.vocab_size,
                 "sos_idx"    :dataset.sos_idx,
                 "eos_idx"    :dataset.eos_idx,
                 "pad_idx"    :dataset.pad_idx,
                 "device"     :device
                }

## Model initialization
generator = SmilesAutoencoder(**model_configs)

## Configuration save
generator.save_config(filepath_configs)

# %% [markdown]
# ## 8. Train

# %%
df_history, df_history_valid = generator.fit(dataset,
                                             validation_dataset=dataset_valid,
                                             margin=10.,
                                             checkpoint_filepath=filepath_checkpoint)

df_history.to_csv(filepath_history, index=False)
df_history_valid.to_csv(filepath_history_valid, index=False)
# Out:
# [00000000/00100000]  loss(tr): 101.812  loss_recon_src(tr): 3.404  loss_recon_tar(tr): 3.402  loss_recon_neg(tr): 3.405  loss_kld(tr): 1.972  loss_triplet(tr): 9.814  valid_ratio(va): 0.106  similarity(va): 0.003
# [00001000/00100000]  loss(tr): 76.447  loss_recon_src(tr): 0.543  loss_recon_tar(tr): 0.360  loss_recon_neg(tr): 0.437  loss_kld(tr): 15.494  loss_triplet(tr): 6.073
# [00002000/00100000]  loss(tr): 70.370  loss_recon_src(tr): 0.490  loss_recon_tar(tr): 0.300  loss_recon_neg(tr): 0.393  loss_kld(tr): 16.290  loss_triplet(tr): 5.388
# [00003000/00100000]  loss(tr): 60.521  loss_recon_src(tr): 0.437  loss_recon_tar(tr): 0.233  loss_recon_neg(tr): 0.383  loss_kld(tr): 17.942  loss_triplet(tr): 4.240
# [00004000/00100000]  loss(tr): 68.359  loss_recon_src(tr): 0.435  loss_recon_tar(tr): 0.215  loss_recon_neg(tr): 0.365  loss_kld(tr): 18.054  loss_triplet(tr): 5.013
# [00005000/00100000]  loss(tr): 55.676  loss_recon_src(tr): 0.438  loss_recon_tar(tr): 0.201  loss_recon_neg(tr): 0.311  loss_kld(tr): 19.656  loss_triplet(tr): 3.586
# [00006000/00100000]  loss(tr): 66.822  loss_recon_src(tr): 0.430  loss_recon_tar(tr): 0.190  loss_recon_neg(tr): 0.303  loss_kld(tr): 19.235  loss_triplet(tr): 4.743
# [00007000/00100000]  loss(tr): 56.112  loss_recon_src(tr): 0.412  loss_recon_tar(tr): 0.193  loss_recon_neg(tr): 0.311  loss_kld(tr): 19.615  loss_triplet(tr): 3.634
# [00008000/00100000]  loss(tr): 45.213  loss_recon_src(tr): 0.385  loss_recon_tar(tr): 0.186  loss_recon_neg(tr): 0.293  loss_kld(tr): 19.794  loss_triplet(tr): 2.527
# [00009000/00100000]  loss(tr): 53.290  loss_recon_src(tr): 0.387  loss_recon_tar(tr): 0.170  loss_recon_neg(tr): 0.281  loss_kld(tr): 19.389  loss_triplet(tr): 3.376
# [00010000/00100000]  loss(tr): 59.456  loss_recon_src(tr): 0.395  loss_recon_tar(tr): 0.173  loss_recon_neg(tr): 0.289  loss_kld(tr): 18.814  loss_triplet(tr): 4.050  valid_ratio(va): 1.000  similarity(va): 0.183
# [00011000/00100000]  loss(tr): 56.141  loss_recon_src(tr): 0.424  loss_recon_tar(tr): 0.172  loss_recon_neg(tr): 0.295  loss_kld(tr): 19.323  loss_triplet(tr): 3.667
# [00012000/00100000]  loss(tr): 62.092  loss_recon_src(tr): 0.376  loss_recon_tar(tr): 0.151  loss_recon_neg(tr): 0.297  loss_kld(tr): 19.659  loss_triplet(tr): 4.230
# [00013000/00100000]  loss(tr): 47.801  loss_recon_src(tr): 0.357  loss_recon_tar(tr): 0.170  loss_recon_neg(tr): 0.278  loss_kld(tr): 19.192  loss_triplet(tr): 2.847
# [00014000/00100000]  loss(tr): 56.752  loss_recon_src(tr): 0.342  loss_recon_tar(tr): 0.173  loss_recon_neg(tr): 0.266  loss_kld(tr): 19.705  loss_triplet(tr): 3.692
# [00015000/00100000]  loss(tr): 56.449  loss_recon_src(tr): 0.348  loss_recon_tar(tr): 0.156  loss_recon_neg(tr): 0.275  loss_kld(tr): 18.903  loss_triplet(tr): 3.742
# [00016000/00100000]  loss(tr): 61.483  loss_recon_src(tr): 0.360  loss_recon_tar(tr): 0.165  loss_recon_neg(tr): 0.248  loss_kld(tr): 19.595  loss_triplet(tr): 4.176
# [00017000/00100000]  loss(tr): 59.846  loss_recon_src(tr): 0.374  loss_recon_tar(tr): 0.163  loss_recon_neg(tr): 0.255  loss_kld(tr): 18.744  loss_triplet(tr): 4.097
# [00018000/00100000]  loss(tr): 62.048  loss_recon_src(tr): 0.362  loss_recon_tar(tr): 0.156  loss_recon_neg(tr): 0.264  loss_kld(tr): 19.583  loss_triplet(tr): 4.233
# [00019000/00100000]  loss(tr): 59.701  loss_recon_src(tr): 0.355  loss_recon_tar(tr): 0.147  loss_recon_neg(tr): 0.292  loss_kld(tr): 18.404  loss_triplet(tr): 4.116
# [00020000/00100000]  loss(tr): 56.419  loss_recon_src(tr): 0.350  loss_recon_tar(tr): 0.150  loss_recon_neg(tr): 0.243  loss_kld(tr): 18.917  loss_triplet(tr): 3.738  valid_ratio(va): 1.000  similarity(va): 0.185
# [00021000/00100000]  loss(tr): 49.455  loss_recon_src(tr): 0.324  loss_recon_tar(tr): 0.146  loss_recon_neg(tr): 0.245  loss_kld(tr): 19.841  loss_triplet(tr): 2.950
# [00022000/00100000]  loss(tr): 52.359  loss_recon_src(tr): 0.326  loss_recon_tar(tr): 0.141  loss_recon_neg(tr): 0.255  loss_kld(tr): 21.053  loss_triplet(tr): 3.118
# [00023000/00100000]  loss(tr): 51.202  loss_recon_src(tr): 0.350  loss_recon_tar(tr): 0.146  loss_recon_neg(tr): 0.253  loss_kld(tr): 19.955  loss_triplet(tr): 3.112
# [00024000/00100000]  loss(tr): 57.083  loss_recon_src(tr): 0.345  loss_recon_tar(tr): 0.153  loss_recon_neg(tr): 0.245  loss_kld(tr): 19.638  loss_triplet(tr): 3.732
# [00025000/00100000]  loss(tr): 54.206  loss_recon_src(tr): 0.337  loss_recon_tar(tr): 0.151  loss_recon_neg(tr): 0.235  loss_kld(tr): 19.931  loss_triplet(tr): 3.415
# [00026000/00100000]  loss(tr): 61.700  loss_recon_src(tr): 0.309  loss_recon_tar(tr): 0.160  loss_recon_neg(tr): 0.247  loss_kld(tr): 19.473  loss_triplet(tr): 4.211
# [00027000/00100000]  loss(tr): 57.217  loss_recon_src(tr): 0.336  loss_recon_tar(tr): 0.162  loss_recon_neg(tr): 0.235  loss_kld(tr): 19.374  loss_triplet(tr): 3.772
# [00028000/00100000]  loss(tr): 51.811  loss_recon_src(tr): 0.328  loss_recon_tar(tr): 0.148  loss_recon_neg(tr): 0.249  loss_kld(tr): 20.191  loss_triplet(tr): 3.150
# [00029000/00100000]  loss(tr): 53.509  loss_recon_src(tr): 0.321  loss_recon_tar(tr): 0.155  loss_recon_neg(tr): 0.226  loss_kld(tr): 19.022  loss_triplet(tr): 3.437
# [00030000/00100000]  loss(tr): 59.252  loss_recon_src(tr): 0.302  loss_recon_tar(tr): 0.156  loss_recon_neg(tr): 0.221  loss_kld(tr): 19.551  loss_triplet(tr): 3.959  valid_ratio(va): 1.000  similarity(va): 0.184
# [00031000/00100000]  loss(tr): 61.342  loss_recon_src(tr): 0.324  loss_recon_tar(tr): 0.145  loss_recon_neg(tr): 0.224  loss_kld(tr): 20.588  loss_triplet(tr): 4.064
# [00032000/00100000]  loss(tr): 53.009  loss_recon_src(tr): 0.344  loss_recon_tar(tr): 0.156  loss_recon_neg(tr): 0.259  loss_kld(tr): 19.023  loss_triplet(tr): 3.386
# [00033000/00100000]  loss(tr): 50.649  loss_recon_src(tr): 0.322  loss_recon_tar(tr): 0.145  loss_recon_neg(tr): 0.247  loss_kld(tr): 19.811  loss_triplet(tr): 3.072
# [00034000/00100000]  loss(tr): 51.913  loss_recon_src(tr): 0.304  loss_recon_tar(tr): 0.151  loss_recon_neg(tr): 0.245  loss_kld(tr): 19.358  loss_triplet(tr): 3.244
# [00035000/00100000]  loss(tr): 56.507  loss_recon_src(tr): 0.301  loss_recon_tar(tr): 0.157  loss_recon_neg(tr): 0.255  loss_kld(tr): 19.293  loss_triplet(tr): 3.709
# [00036000/00100000]  loss(tr): 64.819  loss_recon_src(tr): 0.336  loss_recon_tar(tr): 0.154  loss_recon_neg(tr): 0.248  loss_kld(tr): 18.797  loss_triplet(tr): 4.590
# [00037000/00100000]  loss(tr): 53.031  loss_recon_src(tr): 0.307  loss_recon_tar(tr): 0.144  loss_recon_neg(tr): 0.240  loss_kld(tr): 19.045  loss_triplet(tr): 3.387
# [00038000/00100000]  loss(tr): 51.351  loss_recon_src(tr): 0.317  loss_recon_tar(tr): 0.138  loss_recon_neg(tr): 0.230  loss_kld(tr): 19.505  loss_triplet(tr): 3.173
# [00039000/00100000]  loss(tr): 60.708  loss_recon_src(tr): 0.294  loss_recon_tar(tr): 0.151  loss_recon_neg(tr): 0.232  loss_kld(tr): 19.439  loss_triplet(tr): 4.116
# [00040000/00100000]  loss(tr): 54.452  loss_recon_src(tr): 0.339  loss_recon_tar(tr): 0.147  loss_recon_neg(tr): 0.219  loss_kld(tr): 19.043  loss_triplet(tr): 3.529  valid_ratio(va): 1.000  similarity(va): 0.186
# [00041000/00100000]  loss(tr): 50.147  loss_recon_src(tr): 0.306  loss_recon_tar(tr): 0.156  loss_recon_neg(tr): 0.241  loss_kld(tr): 19.251  loss_triplet(tr): 3.078
# [00042000/00100000]  loss(tr): 56.295  loss_recon_src(tr): 0.298  loss_recon_tar(tr): 0.140  loss_recon_neg(tr): 0.248  loss_kld(tr): 19.418  loss_triplet(tr): 3.676
# [00043000/00100000]  loss(tr): 43.210  loss_recon_src(tr): 0.305  loss_recon_tar(tr): 0.142  loss_recon_neg(tr): 0.209  loss_kld(tr): 19.478  loss_triplet(tr): 2.362
# [00044000/00100000]  loss(tr): 61.152  loss_recon_src(tr): 0.323  loss_recon_tar(tr): 0.152  loss_recon_neg(tr): 0.245  loss_kld(tr): 19.423  loss_triplet(tr): 4.161
# [00045000/00100000]  loss(tr): 54.553  loss_recon_src(tr): 0.321  loss_recon_tar(tr): 0.157  loss_recon_neg(tr): 0.244  loss_kld(tr): 19.585  loss_triplet(tr): 3.485
# [00046000/00100000]  loss(tr): 54.326  loss_recon_src(tr): 0.310  loss_recon_tar(tr): 0.139  loss_recon_neg(tr): 0.223  loss_kld(tr): 18.933  loss_triplet(tr): 3.528
# [00047000/00100000]  loss(tr): 68.044  loss_recon_src(tr): 0.332  loss_recon_tar(tr): 0.142  loss_recon_neg(tr): 0.244  loss_kld(tr): 19.679  loss_triplet(tr): 4.825
# [00048000/00100000]  loss(tr): 52.626  loss_recon_src(tr): 0.309  loss_recon_tar(tr): 0.158  loss_recon_neg(tr): 0.243  loss_kld(tr): 19.039  loss_triplet(tr): 3.347
# [00049000/00100000]  loss(tr): 65.976  loss_recon_src(tr): 0.306  loss_recon_tar(tr): 0.143  loss_recon_neg(tr): 0.202  loss_kld(tr): 19.234  loss_triplet(tr): 4.663
# [00050000/00100000]  loss(tr): 52.717  loss_recon_src(tr): 0.309  loss_recon_tar(tr): 0.150  loss_recon_neg(tr): 0.246  loss_kld(tr): 19.503  loss_triplet(tr): 3.310  valid_ratio(va): 1.000  similarity(va): 0.185
# [00051000/00100000]  loss(tr): 51.109  loss_recon_src(tr): 0.292  loss_recon_tar(tr): 0.133  loss_recon_neg(tr): 0.220  loss_kld(tr): 19.469  loss_triplet(tr): 3.153
# [00052000/00100000]  loss(tr): 50.205  loss_recon_src(tr): 0.337  loss_recon_tar(tr): 0.141  loss_recon_neg(tr): 0.258  loss_kld(tr): 19.448  loss_triplet(tr): 3.063
# [00053000/00100000]  loss(tr): 58.080  loss_recon_src(tr): 0.297  loss_recon_tar(tr): 0.138  loss_recon_neg(tr): 0.239  loss_kld(tr): 19.442  loss_triplet(tr): 3.853
# [00054000/00100000]  loss(tr): 52.405  loss_recon_src(tr): 0.289  loss_recon_tar(tr): 0.141  loss_recon_neg(tr): 0.197  loss_kld(tr): 19.721  loss_triplet(tr): 3.258
# [00055000/00100000]  loss(tr): 50.084  loss_recon_src(tr): 0.300  loss_recon_tar(tr): 0.152  loss_recon_neg(tr): 0.231  loss_kld(tr): 19.472  loss_triplet(tr): 3.050
# [00056000/00100000]  loss(tr): 53.262  loss_recon_src(tr): 0.334  loss_recon_tar(tr): 0.153  loss_recon_neg(tr): 0.230  loss_kld(tr): 19.168  loss_triplet(tr): 3.397
# [00057000/00100000]  loss(tr): 55.077  loss_recon_src(tr): 0.344  loss_recon_tar(tr): 0.153  loss_recon_neg(tr): 0.217  loss_kld(tr): 18.962  loss_triplet(tr): 3.600
# [00058000/00100000]  loss(tr): 52.692  loss_recon_src(tr): 0.314  loss_recon_tar(tr): 0.164  loss_recon_neg(tr): 0.239  loss_kld(tr): 19.403  loss_triplet(tr): 3.317
# [00059000/00100000]  loss(tr): 56.825  loss_recon_src(tr): 0.295  loss_recon_tar(tr): 0.143  loss_recon_neg(tr): 0.232  loss_kld(tr): 19.581  loss_triplet(tr): 3.713
# [00060000/00100000]  loss(tr): 57.951  loss_recon_src(tr): 0.333  loss_recon_tar(tr): 0.152  loss_recon_neg(tr): 0.215  loss_kld(tr): 18.281  loss_triplet(tr): 3.955  valid_ratio(va): 1.000  similarity(va): 0.184
# [00061000/00100000]  loss(tr): 56.821  loss_recon_src(tr): 0.301  loss_recon_tar(tr): 0.132  loss_recon_neg(tr): 0.227  loss_kld(tr): 19.554  loss_triplet(tr): 3.716
# [00062000/00100000]  loss(tr): 54.533  loss_recon_src(tr): 0.319  loss_recon_tar(tr): 0.148  loss_recon_neg(tr): 0.231  loss_kld(tr): 18.839  loss_triplet(tr): 3.558
# [00063000/00100000]  loss(tr): 61.152  loss_recon_src(tr): 0.329  loss_recon_tar(tr): 0.156  loss_recon_neg(tr): 0.241  loss_kld(tr): 19.082  loss_triplet(tr): 4.195
# [00064000/00100000]  loss(tr): 51.939  loss_recon_src(tr): 0.313  loss_recon_tar(tr): 0.150  loss_recon_neg(tr): 0.221  loss_kld(tr): 19.687  loss_triplet(tr): 3.214
# [00065000/00100000]  loss(tr): 54.830  loss_recon_src(tr): 0.295  loss_recon_tar(tr): 0.140  loss_recon_neg(tr): 0.238  loss_kld(tr): 19.308  loss_triplet(tr): 3.541
# [00066000/00100000]  loss(tr): 60.995  loss_recon_src(tr): 0.297  loss_recon_tar(tr): 0.159  loss_recon_neg(tr): 0.239  loss_kld(tr): 19.200  loss_triplet(tr): 4.168
# [00067000/00100000]  loss(tr): 60.057  loss_recon_src(tr): 0.290  loss_recon_tar(tr): 0.159  loss_recon_neg(tr): 0.231  loss_kld(tr): 19.361  loss_triplet(tr): 4.058
# [00068000/00100000]  loss(tr): 58.137  loss_recon_src(tr): 0.306  loss_recon_tar(tr): 0.147  loss_recon_neg(tr): 0.227  loss_kld(tr): 19.869  loss_triplet(tr): 3.816
# [00069000/00100000]  loss(tr): 55.740  loss_recon_src(tr): 0.315  loss_recon_tar(tr): 0.153  loss_recon_neg(tr): 0.230  loss_kld(tr): 19.075  loss_triplet(tr): 3.655
# [00070000/00100000]  loss(tr): 53.400  loss_recon_src(tr): 0.287  loss_recon_tar(tr): 0.138  loss_recon_neg(tr): 0.229  loss_kld(tr): 19.602  loss_triplet(tr): 3.369  valid_ratio(va): 1.000  similarity(va): 0.184
# [00071000/00100000]  loss(tr): 49.959  loss_recon_src(tr): 0.287  loss_recon_tar(tr): 0.153  loss_recon_neg(tr): 0.228  loss_kld(tr): 19.473  loss_triplet(tr): 3.037
# [00072000/00100000]  loss(tr): 57.939  loss_recon_src(tr): 0.313  loss_recon_tar(tr): 0.142  loss_recon_neg(tr): 0.209  loss_kld(tr): 19.424  loss_triplet(tr): 3.841
# [00073000/00100000]  loss(tr): 58.194  loss_recon_src(tr): 0.280  loss_recon_tar(tr): 0.136  loss_recon_neg(tr): 0.222  loss_kld(tr): 18.846  loss_triplet(tr): 3.924
# [00074000/00100000]  loss(tr): 52.805  loss_recon_src(tr): 0.278  loss_recon_tar(tr): 0.139  loss_recon_neg(tr): 0.207  loss_kld(tr): 18.816  loss_triplet(tr): 3.388
# [00075000/00100000]  loss(tr): 54.670  loss_recon_src(tr): 0.304  loss_recon_tar(tr): 0.141  loss_recon_neg(tr): 0.223  loss_kld(tr): 19.737  loss_triplet(tr): 3.482
# [00076000/00100000]  loss(tr): 61.330  loss_recon_src(tr): 0.296  loss_recon_tar(tr): 0.144  loss_recon_neg(tr): 0.247  loss_kld(tr): 19.877  loss_triplet(tr): 4.134
# [00077000/00100000]  loss(tr): 58.191  loss_recon_src(tr): 0.278  loss_recon_tar(tr): 0.143  loss_recon_neg(tr): 0.203  loss_kld(tr): 19.907  loss_triplet(tr): 3.818
# [00078000/00100000]  loss(tr): 59.670  loss_recon_src(tr): 0.278  loss_recon_tar(tr): 0.151  loss_recon_neg(tr): 0.247  loss_kld(tr): 19.366  loss_triplet(tr): 4.019
# [00079000/00100000]  loss(tr): 52.178  loss_recon_src(tr): 0.311  loss_recon_tar(tr): 0.152  loss_recon_neg(tr): 0.212  loss_kld(tr): 19.545  loss_triplet(tr): 3.252
# [00080000/00100000]  loss(tr): 57.260  loss_recon_src(tr): 0.298  loss_recon_tar(tr): 0.144  loss_recon_neg(tr): 0.211  loss_kld(tr): 19.007  loss_triplet(tr): 3.814  valid_ratio(va): 1.000  similarity(va): 0.185
# [00081000/00100000]  loss(tr): 51.109  loss_recon_src(tr): 0.296  loss_recon_tar(tr): 0.138  loss_recon_neg(tr): 0.225  loss_kld(tr): 19.593  loss_triplet(tr): 3.141
# [00082000/00100000]  loss(tr): 52.947  loss_recon_src(tr): 0.290  loss_recon_tar(tr): 0.139  loss_recon_neg(tr): 0.233  loss_kld(tr): 19.190  loss_triplet(tr): 3.365
# [00083000/00100000]  loss(tr): 59.924  loss_recon_src(tr): 0.283  loss_recon_tar(tr): 0.137  loss_recon_neg(tr): 0.241  loss_kld(tr): 19.949  loss_triplet(tr): 3.986
# [00084000/00100000]  loss(tr): 66.088  loss_recon_src(tr): 0.262  loss_recon_tar(tr): 0.140  loss_recon_neg(tr): 0.223  loss_kld(tr): 19.256  loss_triplet(tr): 4.673
# [00085000/00100000]  loss(tr): 56.905  loss_recon_src(tr): 0.308  loss_recon_tar(tr): 0.146  loss_recon_neg(tr): 0.218  loss_kld(tr): 19.536  loss_triplet(tr): 3.726
# [00086000/00100000]  loss(tr): 53.170  loss_recon_src(tr): 0.278  loss_recon_tar(tr): 0.137  loss_recon_neg(tr): 0.236  loss_kld(tr): 18.724  loss_triplet(tr): 3.434
# [00087000/00100000]  loss(tr): 55.673  loss_recon_src(tr): 0.316  loss_recon_tar(tr): 0.141  loss_recon_neg(tr): 0.229  loss_kld(tr): 19.334  loss_triplet(tr): 3.622
# [00088000/00100000]  loss(tr): 57.967  loss_recon_src(tr): 0.278  loss_recon_tar(tr): 0.141  loss_recon_neg(tr): 0.227  loss_kld(tr): 19.343  loss_triplet(tr): 3.852
# [00089000/00100000]  loss(tr): 54.960  loss_recon_src(tr): 0.305  loss_recon_tar(tr): 0.146  loss_recon_neg(tr): 0.214  loss_kld(tr): 19.221  loss_triplet(tr): 3.563
# [00090000/00100000]  loss(tr): 46.618  loss_recon_src(tr): 0.285  loss_recon_tar(tr): 0.156  loss_recon_neg(tr): 0.247  loss_kld(tr): 19.630  loss_triplet(tr): 2.687  valid_ratio(va): 1.000  similarity(va): 0.184
# [00091000/00100000]  loss(tr): 56.499  loss_recon_src(tr): 0.285  loss_recon_tar(tr): 0.141  loss_recon_neg(tr): 0.253  loss_kld(tr): 18.923  loss_triplet(tr): 3.746
# [00092000/00100000]  loss(tr): 46.719  loss_recon_src(tr): 0.296  loss_recon_tar(tr): 0.147  loss_recon_neg(tr): 0.234  loss_kld(tr): 19.409  loss_triplet(tr): 2.720
# [00093000/00100000]  loss(tr): 53.826  loss_recon_src(tr): 0.307  loss_recon_tar(tr): 0.155  loss_recon_neg(tr): 0.223  loss_kld(tr): 19.231  loss_triplet(tr): 3.448
# [00094000/00100000]  loss(tr): 49.157  loss_recon_src(tr): 0.295  loss_recon_tar(tr): 0.144  loss_recon_neg(tr): 0.226  loss_kld(tr): 19.577  loss_triplet(tr): 2.947
# [00095000/00100000]  loss(tr): 60.056  loss_recon_src(tr): 0.309  loss_recon_tar(tr): 0.144  loss_recon_neg(tr): 0.219  loss_kld(tr): 19.492  loss_triplet(tr): 4.045
# [00096000/00100000]  loss(tr): 58.026  loss_recon_src(tr): 0.280  loss_recon_tar(tr): 0.140  loss_recon_neg(tr): 0.222  loss_kld(tr): 19.640  loss_triplet(tr): 3.828
# [00097000/00100000]  loss(tr): 62.448  loss_recon_src(tr): 0.275  loss_recon_tar(tr): 0.148  loss_recon_neg(tr): 0.222  loss_kld(tr): 19.528  loss_triplet(tr): 4.281
# [00098000/00100000]  loss(tr): 48.125  loss_recon_src(tr): 0.273  loss_recon_tar(tr): 0.141  loss_recon_neg(tr): 0.232  loss_kld(tr): 19.809  loss_triplet(tr): 2.821
# [00099000/00100000]  loss(tr): 58.375  loss_recon_src(tr): 0.302  loss_recon_tar(tr): 0.150  loss_recon_neg(tr): 0.235  loss_kld(tr): 18.779  loss_triplet(tr): 3.948
# [00100000/00100000]  loss(tr): 45.592  loss_recon_src(tr): 0.296  loss_recon_tar(tr): 0.133  loss_recon_neg(tr): 0.213  loss_kld(tr): 19.205  loss_triplet(tr): 2.628  valid_ratio(va): 1.000  similarity(va): 0.183

# %% [markdown]
# ## 9. Visualize for loss analysis

# %%
fig, axes = plt.subplots(4,1,figsize=(8,8))

axes[0].plot(df_history.loc[:,"LOSS_TOTAL"], label="Total loss")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_SOURCE"], label="Recon. loss (src)")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_TARGET"], label="Recon. loss (tar)")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_NEGATIVE"], label="Recon. loss (neg)")
axes[2].plot(df_history.loc[:,"LOSS_KL_DIVERGENCE"], label="KLD loss (src,tar)")
axes[3].plot(df_history.loc[:,"LOSS_TRIPLET"], label="Triplet loss (src,tar,neg)")

axes[3].set_xlabel("Iteration")
for ax in axes:
    ax.legend(loc='best')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,1,figsize=(8,4))

axes[0].plot(df_history_valid.loc[:,"VALID_RATIO"], label="Validity")
axes[1].plot(df_history_valid.loc[:,"AVERAGE_SIMILARITY"], label="Tanimoto coeff.")

axes[1].set_xlabel("Iteration")
for ax in axes:
    ax.legend(loc='best')

plt.tight_layout()
plt.show()
