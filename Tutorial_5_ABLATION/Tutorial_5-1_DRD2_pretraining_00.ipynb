# %% [markdown]
# # Tutorial - Step1: MTMR pretraining without both contractive and margin losses

# %% [markdown]
# ## 1. Import requirements

# %%
import os
import sys
import pandas as pd
import torch
import time
import matplotlib.pyplot as plt

# %%
sys.path = [os.path.abspath(os.path.join(os.getcwd(), os.pardir))] + sys.path

# %%
from MTMR.dataset import TrainingSmilesDataset, ValidationSmilesDataset
from MTMR.vae import SmilesAutoencoder

# %% [markdown]
# ## 2. Configure GPU (if available)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# ## 3. Specify a target property

# %%
PROPERTY_NAME = "drd2"
TEST_NUM = "00"

# %% [markdown]
# ## 4. Set directories (for inputs and outputs)

# %%
input_dir = os.path.abspath(os.path.join(os.pardir, "DATA", PROPERTY_NAME))

# %%
output_dir = f"outputs_5-1_{PROPERTY_NAME.upper()}_pretraining_{TEST_NUM}"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

# %% [markdown]
# ## 5. Set file names

# %%
filepath_train = os.path.join(input_dir, "rdkit_train_triplet.txt")
filepath_valid = os.path.join(input_dir, "rdkit_valid.txt")

# %%
filepath_char2idx      = os.path.join(output_dir, "char2idx.csv")
filepath_configs       = os.path.join(output_dir, "configs.csv")
filepath_checkpoint    = os.path.join(output_dir, "checkpoints.pt")
filepath_history       = os.path.join(output_dir, "history.csv")
filepath_history_valid = os.path.join(output_dir, "history_valid.csv")

# %% [markdown]
# ## 6. Load datasets (for training and validation)

# %%
dataset = TrainingSmilesDataset(filepath_train, device=device)
dataset.save_char2idx(filepath_char2idx)
dataset_valid = ValidationSmilesDataset(filepath_valid, filepath_char2idx, device=device)

# %% [markdown]
# ## 7. Initialize a generator of MTMR

# %%
## Model configuration
model_configs = {"hidden_size":128,
                 "latent_size":128,
                 "num_layers" :2,
                 "vocab_size" :dataset.vocab_size,
                 "sos_idx"    :dataset.sos_idx,
                 "eos_idx"    :dataset.eos_idx,
                 "pad_idx"    :dataset.pad_idx,
                 "device"     :device
                }

## Model initialization
generator = SmilesAutoencoder(**model_configs)

## Configuration save
generator.save_config(filepath_configs)

# %% [markdown]
# ## 8. Train

# %%
df_history, df_history_valid = generator.fit(dataset,
                                             validation_dataset=dataset_valid,
                                             use_contractive=False,
                                             use_margin=False,
                                             checkpoint_filepath=filepath_checkpoint)

df_history.to_csv(filepath_history, index=False)
df_history_valid.to_csv(filepath_history_valid, index=False)
# Out:
# [00000000/00100000]  loss(tr): 3.379  loss_recon_src(tr): 3.375  loss_recon_tar(tr): 3.376  loss_recon_neg(tr): 3.384  loss_contractive(tr): 0.718  loss_margin(tr): 1.703  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.132  similarity(va): 0.003
# [00001000/00100000]  loss(tr): 0.358  loss_recon_src(tr): 0.448  loss_recon_tar(tr): 0.274  loss_recon_neg(tr): 0.355  loss_contractive(tr): 346.269  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.858  similarity(va): 0.209
# [00002000/00100000]  loss(tr): 0.196  loss_recon_src(tr): 0.263  loss_recon_tar(tr): 0.143  loss_recon_neg(tr): 0.184  loss_contractive(tr): 338.659  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.912  similarity(va): 0.301
# [00003000/00100000]  loss(tr): 0.121  loss_recon_src(tr): 0.190  loss_recon_tar(tr): 0.041  loss_recon_neg(tr): 0.130  loss_contractive(tr): 367.046  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.938  similarity(va): 0.366
# [00004000/00100000]  loss(tr): 0.083  loss_recon_src(tr): 0.133  loss_recon_tar(tr): 0.026  loss_recon_neg(tr): 0.088  loss_contractive(tr): 367.297  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.966  similarity(va): 0.429
# [00005000/00100000]  loss(tr): 0.060  loss_recon_src(tr): 0.101  loss_recon_tar(tr): 0.026  loss_recon_neg(tr): 0.055  loss_contractive(tr): 384.794  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.956  similarity(va): 0.451
# [00006000/00100000]  loss(tr): 0.049  loss_recon_src(tr): 0.082  loss_recon_tar(tr): 0.012  loss_recon_neg(tr): 0.051  loss_contractive(tr): 377.008  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.944  similarity(va): 0.461
# [00007000/00100000]  loss(tr): 0.037  loss_recon_src(tr): 0.059  loss_recon_tar(tr): 0.011  loss_recon_neg(tr): 0.039  loss_contractive(tr): 386.524  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.906  similarity(va): 0.448
# [00008000/00100000]  loss(tr): 0.030  loss_recon_src(tr): 0.058  loss_recon_tar(tr): 0.009  loss_recon_neg(tr): 0.025  loss_contractive(tr): 378.951  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.912  similarity(va): 0.452
# [00009000/00100000]  loss(tr): 0.024  loss_recon_src(tr): 0.035  loss_recon_tar(tr): 0.007  loss_recon_neg(tr): 0.029  loss_contractive(tr): 383.832  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.900  similarity(va): 0.464
# [00010000/00100000]  loss(tr): 0.025  loss_recon_src(tr): 0.047  loss_recon_tar(tr): 0.006  loss_recon_neg(tr): 0.023  loss_contractive(tr): 380.487  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.886  similarity(va): 0.458
# [00011000/00100000]  loss(tr): 0.020  loss_recon_src(tr): 0.028  loss_recon_tar(tr): 0.005  loss_recon_neg(tr): 0.024  loss_contractive(tr): 385.142  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.896  similarity(va): 0.457
# [00012000/00100000]  loss(tr): 0.019  loss_recon_src(tr): 0.034  loss_recon_tar(tr): 0.007  loss_recon_neg(tr): 0.018  loss_contractive(tr): 370.664  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.854  similarity(va): 0.434
# [00013000/00100000]  loss(tr): 0.019  loss_recon_src(tr): 0.030  loss_recon_tar(tr): 0.005  loss_recon_neg(tr): 0.020  loss_contractive(tr): 370.148  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.870  similarity(va): 0.462
# [00014000/00100000]  loss(tr): 0.012  loss_recon_src(tr): 0.021  loss_recon_tar(tr): 0.003  loss_recon_neg(tr): 0.013  loss_contractive(tr): 356.671  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.860  similarity(va): 0.454
# [00015000/00100000]  loss(tr): 0.022  loss_recon_src(tr): 0.032  loss_recon_tar(tr): 0.010  loss_recon_neg(tr): 0.023  loss_contractive(tr): 378.546  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.884  similarity(va): 0.475
# [00016000/00100000]  loss(tr): 0.011  loss_recon_src(tr): 0.018  loss_recon_tar(tr): 0.003  loss_recon_neg(tr): 0.011  loss_contractive(tr): 367.692  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.824  similarity(va): 0.439
# [00017000/00100000]  loss(tr): 0.013  loss_recon_src(tr): 0.023  loss_recon_tar(tr): 0.003  loss_recon_neg(tr): 0.014  loss_contractive(tr): 363.226  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.818  similarity(va): 0.434
# [00018000/00100000]  loss(tr): 0.010  loss_recon_src(tr): 0.013  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.013  loss_contractive(tr): 374.510  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.844  similarity(va): 0.442
# [00019000/00100000]  loss(tr): 0.012  loss_recon_src(tr): 0.021  loss_recon_tar(tr): 0.003  loss_recon_neg(tr): 0.013  loss_contractive(tr): 364.688  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.812  similarity(va): 0.426
# [00020000/00100000]  loss(tr): 0.012  loss_recon_src(tr): 0.011  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.020  loss_contractive(tr): 369.314  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.856  similarity(va): 0.462
# [00021000/00100000]  loss(tr): 0.012  loss_recon_src(tr): 0.023  loss_recon_tar(tr): 0.003  loss_recon_neg(tr): 0.010  loss_contractive(tr): 346.224  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.818  similarity(va): 0.428
# [00022000/00100000]  loss(tr): 0.013  loss_recon_src(tr): 0.019  loss_recon_tar(tr): 0.007  loss_recon_neg(tr): 0.013  loss_contractive(tr): 334.616  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.816  similarity(va): 0.431
# [00023000/00100000]  loss(tr): 0.009  loss_recon_src(tr): 0.016  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.009  loss_contractive(tr): 343.685  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.818  similarity(va): 0.438
# [00024000/00100000]  loss(tr): 0.011  loss_recon_src(tr): 0.023  loss_recon_tar(tr): 0.003  loss_recon_neg(tr): 0.009  loss_contractive(tr): 356.245  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.818  similarity(va): 0.435
# [00025000/00100000]  loss(tr): 0.011  loss_recon_src(tr): 0.018  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.014  loss_contractive(tr): 350.884  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.792  similarity(va): 0.424
# [00026000/00100000]  loss(tr): 0.007  loss_recon_src(tr): 0.012  loss_recon_tar(tr): 0.005  loss_recon_neg(tr): 0.005  loss_contractive(tr): 327.701  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.798  similarity(va): 0.434
# [00027000/00100000]  loss(tr): 0.010  loss_recon_src(tr): 0.017  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.012  loss_contractive(tr): 329.970  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.798  similarity(va): 0.425
# [00028000/00100000]  loss(tr): 0.007  loss_recon_src(tr): 0.013  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.006  loss_contractive(tr): 329.173  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.776  similarity(va): 0.420
# [00029000/00100000]  loss(tr): 0.006  loss_recon_src(tr): 0.009  loss_recon_tar(tr): 0.003  loss_recon_neg(tr): 0.007  loss_contractive(tr): 334.023  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.780  similarity(va): 0.429
# [00030000/00100000]  loss(tr): 0.006  loss_recon_src(tr): 0.011  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.007  loss_contractive(tr): 291.940  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.764  similarity(va): 0.423
# [00031000/00100000]  loss(tr): 0.010  loss_recon_src(tr): 0.015  loss_recon_tar(tr): 0.004  loss_recon_neg(tr): 0.010  loss_contractive(tr): 309.908  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.796  similarity(va): 0.433
# [00032000/00100000]  loss(tr): 0.009  loss_recon_src(tr): 0.014  loss_recon_tar(tr): 0.006  loss_recon_neg(tr): 0.007  loss_contractive(tr): 326.297  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.784  similarity(va): 0.437
# [00033000/00100000]  loss(tr): 0.008  loss_recon_src(tr): 0.012  loss_recon_tar(tr): 0.004  loss_recon_neg(tr): 0.007  loss_contractive(tr): 316.270  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.768  similarity(va): 0.426
# [00034000/00100000]  loss(tr): 0.009  loss_recon_src(tr): 0.015  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.009  loss_contractive(tr): 302.118  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.782  similarity(va): 0.429
# [00035000/00100000]  loss(tr): 0.005  loss_recon_src(tr): 0.009  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.004  loss_contractive(tr): 293.390  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.734  similarity(va): 0.416
# [00036000/00100000]  loss(tr): 0.006  loss_recon_src(tr): 0.008  loss_recon_tar(tr): 0.003  loss_recon_neg(tr): 0.006  loss_contractive(tr): 302.835  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.786  similarity(va): 0.431
# [00037000/00100000]  loss(tr): 0.008  loss_recon_src(tr): 0.014  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.009  loss_contractive(tr): 287.402  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.756  similarity(va): 0.422
# [00038000/00100000]  loss(tr): 0.008  loss_recon_src(tr): 0.011  loss_recon_tar(tr): 0.005  loss_recon_neg(tr): 0.008  loss_contractive(tr): 298.360  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.740  similarity(va): 0.412
# [00039000/00100000]  loss(tr): 0.005  loss_recon_src(tr): 0.009  loss_recon_tar(tr): 0.003  loss_recon_neg(tr): 0.003  loss_contractive(tr): 286.311  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.750  similarity(va): 0.423
# [00040000/00100000]  loss(tr): 0.005  loss_recon_src(tr): 0.008  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.007  loss_contractive(tr): 286.775  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.768  similarity(va): 0.433
# [00041000/00100000]  loss(tr): 0.006  loss_recon_src(tr): 0.014  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.004  loss_contractive(tr): 273.014  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.770  similarity(va): 0.426
# [00042000/00100000]  loss(tr): 0.004  loss_recon_src(tr): 0.006  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.005  loss_contractive(tr): 268.949  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.760  similarity(va): 0.436
# [00043000/00100000]  loss(tr): 0.007  loss_recon_src(tr): 0.010  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.007  loss_contractive(tr): 256.121  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.736  similarity(va): 0.412
# [00044000/00100000]  loss(tr): 0.005  loss_recon_src(tr): 0.010  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.005  loss_contractive(tr): 270.651  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.738  similarity(va): 0.408
# [00045000/00100000]  loss(tr): 0.004  loss_recon_src(tr): 0.005  loss_recon_tar(tr): 0.003  loss_recon_neg(tr): 0.003  loss_contractive(tr): 255.626  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.736  similarity(va): 0.409
# [00046000/00100000]  loss(tr): 0.006  loss_recon_src(tr): 0.012  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.006  loss_contractive(tr): 242.241  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.746  similarity(va): 0.418
# [00047000/00100000]  loss(tr): 0.005  loss_recon_src(tr): 0.007  loss_recon_tar(tr): 0.004  loss_recon_neg(tr): 0.005  loss_contractive(tr): 253.960  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.720  similarity(va): 0.406
# [00048000/00100000]  loss(tr): 0.005  loss_recon_src(tr): 0.009  loss_recon_tar(tr): 0.003  loss_recon_neg(tr): 0.004  loss_contractive(tr): 238.331  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.740  similarity(va): 0.422
# [00049000/00100000]  loss(tr): 0.005  loss_recon_src(tr): 0.010  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.003  loss_contractive(tr): 234.447  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.728  similarity(va): 0.408
# [00050000/00100000]  loss(tr): 0.005  loss_recon_src(tr): 0.010  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.004  loss_contractive(tr): 244.829  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.720  similarity(va): 0.419
# [00051000/00100000]  loss(tr): 0.005  loss_recon_src(tr): 0.008  loss_recon_tar(tr): 0.003  loss_recon_neg(tr): 0.005  loss_contractive(tr): 220.952  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.710  similarity(va): 0.401
# [00052000/00100000]  loss(tr): 0.005  loss_recon_src(tr): 0.009  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.004  loss_contractive(tr): 223.661  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.712  similarity(va): 0.398
# [00053000/00100000]  loss(tr): 0.005  loss_recon_src(tr): 0.008  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.005  loss_contractive(tr): 217.433  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.724  similarity(va): 0.403
# [00054000/00100000]  loss(tr): 0.005  loss_recon_src(tr): 0.010  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.004  loss_contractive(tr): 206.009  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.700  similarity(va): 0.391
# [00055000/00100000]  loss(tr): 0.005  loss_recon_src(tr): 0.010  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.003  loss_contractive(tr): 204.597  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.718  similarity(va): 0.414
# [00056000/00100000]  loss(tr): 0.006  loss_recon_src(tr): 0.011  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.005  loss_contractive(tr): 209.723  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.728  similarity(va): 0.406
# [00057000/00100000]  loss(tr): 0.005  loss_recon_src(tr): 0.006  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.008  loss_contractive(tr): 199.774  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.714  similarity(va): 0.402
# [00058000/00100000]  loss(tr): 0.004  loss_recon_src(tr): 0.008  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.003  loss_contractive(tr): 205.258  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.696  similarity(va): 0.387
# [00059000/00100000]  loss(tr): 0.005  loss_recon_src(tr): 0.011  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.004  loss_contractive(tr): 191.626  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.732  similarity(va): 0.423
# [00060000/00100000]  loss(tr): 0.005  loss_recon_src(tr): 0.010  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.004  loss_contractive(tr): 198.919  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.722  similarity(va): 0.414
# [00061000/00100000]  loss(tr): 0.003  loss_recon_src(tr): 0.005  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.004  loss_contractive(tr): 197.196  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.698  similarity(va): 0.394
# [00062000/00100000]  loss(tr): 0.006  loss_recon_src(tr): 0.010  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.006  loss_contractive(tr): 191.549  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.712  similarity(va): 0.407
# [00063000/00100000]  loss(tr): 0.003  loss_recon_src(tr): 0.005  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.003  loss_contractive(tr): 181.839  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.726  similarity(va): 0.417
# [00064000/00100000]  loss(tr): 0.003  loss_recon_src(tr): 0.006  loss_recon_tar(tr): 0.000  loss_recon_neg(tr): 0.003  loss_contractive(tr): 182.917  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.716  similarity(va): 0.408
# [00065000/00100000]  loss(tr): 0.003  loss_recon_src(tr): 0.006  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.002  loss_contractive(tr): 167.801  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.714  similarity(va): 0.407
# [00066000/00100000]  loss(tr): 0.006  loss_recon_src(tr): 0.011  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.006  loss_contractive(tr): 173.721  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.686  similarity(va): 0.391
# [00067000/00100000]  loss(tr): 0.004  loss_recon_src(tr): 0.008  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.003  loss_contractive(tr): 173.839  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.700  similarity(va): 0.396
# [00068000/00100000]  loss(tr): 0.004  loss_recon_src(tr): 0.006  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.004  loss_contractive(tr): 165.857  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.706  similarity(va): 0.402
# [00069000/00100000]  loss(tr): 0.002  loss_recon_src(tr): 0.004  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.002  loss_contractive(tr): 172.941  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.718  similarity(va): 0.409
# [00070000/00100000]  loss(tr): 0.006  loss_recon_src(tr): 0.011  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.006  loss_contractive(tr): 179.673  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.688  similarity(va): 0.398
# [00071000/00100000]  loss(tr): 0.003  loss_recon_src(tr): 0.005  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.003  loss_contractive(tr): 162.958  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.696  similarity(va): 0.401
# [00072000/00100000]  loss(tr): 0.004  loss_recon_src(tr): 0.009  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.004  loss_contractive(tr): 165.024  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.654  similarity(va): 0.380
# [00073000/00100000]  loss(tr): 0.004  loss_recon_src(tr): 0.006  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.004  loss_contractive(tr): 147.316  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.658  similarity(va): 0.373
# [00074000/00100000]  loss(tr): 0.003  loss_recon_src(tr): 0.005  loss_recon_tar(tr): 0.000  loss_recon_neg(tr): 0.003  loss_contractive(tr): 149.748  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.662  similarity(va): 0.373
# [00075000/00100000]  loss(tr): 0.007  loss_recon_src(tr): 0.008  loss_recon_tar(tr): 0.007  loss_recon_neg(tr): 0.006  loss_contractive(tr): 157.283  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.674  similarity(va): 0.388
# [00076000/00100000]  loss(tr): 0.006  loss_recon_src(tr): 0.007  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.009  loss_contractive(tr): 146.894  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.680  similarity(va): 0.390
# [00077000/00100000]  loss(tr): 0.004  loss_recon_src(tr): 0.007  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.004  loss_contractive(tr): 144.423  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.702  similarity(va): 0.405
# [00078000/00100000]  loss(tr): 0.004  loss_recon_src(tr): 0.009  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.003  loss_contractive(tr): 140.434  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.672  similarity(va): 0.381
# [00079000/00100000]  loss(tr): 0.003  loss_recon_src(tr): 0.007  loss_recon_tar(tr): 0.000  loss_recon_neg(tr): 0.003  loss_contractive(tr): 136.841  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.656  similarity(va): 0.377
# [00080000/00100000]  loss(tr): 0.004  loss_recon_src(tr): 0.006  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.005  loss_contractive(tr): 140.067  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.632  similarity(va): 0.358
# [00081000/00100000]  loss(tr): 0.004  loss_recon_src(tr): 0.007  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.005  loss_contractive(tr): 141.339  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.640  similarity(va): 0.372
# [00082000/00100000]  loss(tr): 0.003  loss_recon_src(tr): 0.006  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.002  loss_contractive(tr): 140.177  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.656  similarity(va): 0.382
# [00083000/00100000]  loss(tr): 0.003  loss_recon_src(tr): 0.007  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.001  loss_contractive(tr): 139.113  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.682  similarity(va): 0.394
# [00084000/00100000]  loss(tr): 0.011  loss_recon_src(tr): 0.008  loss_recon_tar(tr): 0.006  loss_recon_neg(tr): 0.016  loss_contractive(tr): 134.917  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.734  similarity(va): 0.446
# [00085000/00100000]  loss(tr): 0.004  loss_recon_src(tr): 0.005  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.004  loss_contractive(tr): 125.581  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.678  similarity(va): 0.388
# [00086000/00100000]  loss(tr): 0.002  loss_recon_src(tr): 0.003  loss_recon_tar(tr): 0.000  loss_recon_neg(tr): 0.003  loss_contractive(tr): 121.186  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.658  similarity(va): 0.388
# [00087000/00100000]  loss(tr): 0.003  loss_recon_src(tr): 0.004  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.004  loss_contractive(tr): 124.997  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.648  similarity(va): 0.380
# [00088000/00100000]  loss(tr): 0.003  loss_recon_src(tr): 0.004  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.002  loss_contractive(tr): 122.839  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.676  similarity(va): 0.391
# [00089000/00100000]  loss(tr): 0.003  loss_recon_src(tr): 0.005  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.004  loss_contractive(tr): 122.245  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.678  similarity(va): 0.393
# [00090000/00100000]  loss(tr): 0.002  loss_recon_src(tr): 0.004  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.001  loss_contractive(tr): 123.257  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.646  similarity(va): 0.372
# [00091000/00100000]  loss(tr): 0.004  loss_recon_src(tr): 0.007  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.005  loss_contractive(tr): 124.026  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.670  similarity(va): 0.385
# [00092000/00100000]  loss(tr): 0.003  loss_recon_src(tr): 0.004  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.004  loss_contractive(tr): 115.800  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.626  similarity(va): 0.363
# [00093000/00100000]  loss(tr): 0.004  loss_recon_src(tr): 0.008  loss_recon_tar(tr): 0.002  loss_recon_neg(tr): 0.003  loss_contractive(tr): 114.375  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.642  similarity(va): 0.360
# [00094000/00100000]  loss(tr): 0.004  loss_recon_src(tr): 0.005  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.006  loss_contractive(tr): 120.959  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.614  similarity(va): 0.355
# [00095000/00100000]  loss(tr): 0.005  loss_recon_src(tr): 0.008  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.005  loss_contractive(tr): 110.714  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.644  similarity(va): 0.375
# [00096000/00100000]  loss(tr): 0.004  loss_recon_src(tr): 0.005  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.004  loss_contractive(tr): 108.653  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.636  similarity(va): 0.374
# [00097000/00100000]  loss(tr): 0.003  loss_recon_src(tr): 0.006  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.002  loss_contractive(tr): 109.008  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.652  similarity(va): 0.376
# [00098000/00100000]  loss(tr): 0.003  loss_recon_src(tr): 0.006  loss_recon_tar(tr): 0.000  loss_recon_neg(tr): 0.002  loss_contractive(tr): 109.351  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.654  similarity(va): 0.382
# [00099000/00100000]  loss(tr): 0.004  loss_recon_src(tr): 0.004  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.005  loss_contractive(tr): 103.393  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.656  similarity(va): 0.376
# [00100000/00100000]  loss(tr): 0.003  loss_recon_src(tr): 0.006  loss_recon_tar(tr): 0.001  loss_recon_neg(tr): 0.003  loss_contractive(tr): 104.311  loss_margin(tr): 0.000  beta: 0.000  gamma: 0.000  valid_ratio(va): 0.658  similarity(va): 0.382

# %% [markdown]
# ## 9. Visualize for loss analysis

# %%
fig, axes = plt.subplots(4,1,figsize=(8,8))

axes[0].plot(df_history.loc[:,"LOSS_TOTAL"], label="Total loss")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_SOURCE"], label="Recon. loss (src)")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_TARGET"], label="Recon. loss (tar)")
axes[1].plot(df_history.loc[:,"LOSS_RECONSTRUCTION_NEGATIVE"], label="Recon. loss (neg)")
axes[2].plot(df_history.loc[:,"LOSS_CONTRACTIVE"], label="Contractive loss (src,tar)")
axes[3].plot(df_history.loc[:,"LOSS_MARGIN"], label="Margin loss (src,tar,neg)")

axes[3].set_xlabel("Iteration")
for ax in axes:
    ax.legend(loc='best')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,1,figsize=(8,4))

axes[0].plot(df_history_valid.loc[:,"VALID_RATIO"], label="Validity")
axes[1].plot(df_history_valid.loc[:,"AVERAGE_SIMILARITY"], label="Tanimoto coeff.")

axes[1].set_xlabel("Iteration")
for ax in axes:
    ax.legend(loc='best')

plt.tight_layout()
plt.show()
